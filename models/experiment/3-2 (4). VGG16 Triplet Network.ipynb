# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import random, gc, keras, os, pickle

from keras import backend as K
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential, load_model, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Input, Lambda, MaxPooling2D
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load Data

# %%
train_df = pd.read_csv('./data/triplet/train.csv')
val_df = pd.read_csv('./data/triplet/validation.csv')
test_df = pd.read_csv('./data/triplet/test.csv')

print('Train:\t\t', train_df.shape)
print('Validation:\t', val_df.shape)
print('Test:\t\t', test_df.shape)

print('\nTrain Landmarks:\t', len(train_df['landmark_id'].unique()))
print('Validation Landmarks:\t', len(val_df['landmark_id'].unique()))
print('Test Landmarks:\t\t', len(test_df['landmark_id'].unique()))
# Out:
# Train:		 (113783, 4)
# Validation:	 (22255, 4)
# Test:		 (22391, 4)
#
# Train Landmarks:	 14943
# Validation Landmarks:	 7674
# Test Landmarks:		 14436

# %%
train_df.head()
# Out:
#    image_id                id  \
# 0    465272  a2ccf8ed2e969f6a
# 1     64516  e205ca7c8dd7c027
# 2    928409  4e8ab93c1620e8a3
# 3     88809  896bf928214d1ca4
# 4   1001133  375d2a153bdca926
#
#                                                  url  landmark_id
# 0  https://lh4.googleusercontent.com/-TPHkS5gzvm4...            0
# 1  https://lh3.googleusercontent.com/-V3RjsZtGpxE...            0
# 2  http://mw2.google.com/mw-panoramio/photos/medi...            0
# 3  http://lh5.ggpht.com/-Cy0l41uUaGA/R--yB8vy41I/...            0
# 4  http://lh6.ggpht.com/-UqzFpnqE9bU/S_0u1RovfdI/...            0

# %% [markdown]
# # Helper Functions

# %%
# training set triplet generator
def train_triplet_generator(df, batch_size=74, img_size=(224, 224), seed=42, 
                            prefix='./data/triplet/train/'):
    """ training set triplet generator
        it will generate 7400 triplet images in total
    """
    # get images with only one training image landmark id and the rest landmark ids
    np.random.seed(seed)
    grouped = df[['landmark_id', 'image_id']].groupby('landmark_id').count().reset_index()
    unique_neg_ids = list(grouped[grouped['image_id'] == 1]['landmark_id'].values)
    rest_ids = list(grouped[grouped['image_id'] > 1]['landmark_id'].values)
    size = 7400 * 2 - len(unique_neg_ids) 
    zeros = np.zeros((batch_size, 3, 1), dtype=K.floatx())
    
    while True:
        # get positive and negative image landmark ids
        np.random.shuffle(rest_ids)
        candidate_ids = list(np.random.choice(rest_ids, size=size, replace=False))
        pos_landmark_ids = candidate_ids[:7400]
        neg_landmark_ids = candidate_ids[7400:] + unique_neg_ids
        np.random.shuffle(neg_landmark_ids)
        
        # transform landmark id into image id
        anc_img_ids = []
        pos_img_ids = []
        neg_img_ids = []
        
        for i in range(len(pos_landmark_ids)):
            tmp_pos_ids = df[df['landmark_id'] == pos_landmark_ids[i]]['image_id'].values
            anc_img_ids.append(tmp_pos_ids[0])
            pos_img_ids.append(tmp_pos_ids[1])
            
            tmp_neg_ids = df[df['landmark_id'] == neg_landmark_ids[i]]['image_id'].values
            neg_img_ids.append(tmp_neg_ids[0])
        
        # iterator to read batch images
        for j in range(len(pos_img_ids) // batch_size):
            batch_anc_img_ids = anc_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_pos_img_ids = pos_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_neg_img_ids = neg_img_ids[j * batch_size: (j + 1) * batch_size]
            
            # get images
            anc_imgs = []
            pos_imgs = []
            neg_imgs = []
            
            # iteratively read images
            for k in range(batch_size):
                anc_path = prefix + str(batch_anc_img_ids[k]) + '.jpg'
                pos_path = prefix + str(batch_pos_img_ids[k]) + '.jpg'
                neg_path = prefix + str(batch_neg_img_ids[k]) + '.jpg'
                
                tmp_anc_img = load_img(anc_path, target_size=img_size)
                tmp_anc_img = img_to_array(tmp_anc_img)
                anc_imgs.append(tmp_anc_img)
                
                tmp_pos_img = load_img(pos_path, target_size=img_size)
                tmp_pos_img = img_to_array(tmp_pos_img)
                pos_imgs.append(tmp_pos_img)
                
                tmp_neg_img = load_img(neg_path, target_size=img_size)
                tmp_neg_img = img_to_array(tmp_neg_img)
                neg_imgs.append(tmp_neg_img)
        
            # transform list to array
            anc_imgs = np.array(anc_imgs, dtype=K.floatx()) / 255.0
            pos_imgs = np.array(pos_imgs, dtype=K.floatx()) / 255.0
            neg_imgs = np.array(neg_imgs, dtype=K.floatx()) / 255.0

            yield [anc_imgs, pos_imgs, neg_imgs], zeros

# %%
# validation set triplet generator
def val_triplet_generator(df, batch_size=128, img_size=(224, 224), 
                          seed=42, prefix='./data/triplet/validation'):
    """ validation set triplet collector """
    
     # get images with only one image landmark id and the rest landmark ids
    grouped = df[['landmark_id', 'image_id']].groupby('landmark_id').count().reset_index()
    unique_neg_ids = list(grouped[grouped['image_id'] == 1]['landmark_id'].values)
    rest_ids = list(grouped[grouped['image_id'] > 1]['landmark_id'].values)
    size = 3072 * 2 - len(unique_neg_ids) 
    zeros = np.zeros((batch_size, 3, 1), dtype=K.floatx())
    
    while True:
        # get positive and negative image landmark ids
        np.random.seed(seed)
        candidate_ids = list(np.random.choice(rest_ids, size=size, replace=False))
        pos_landmark_ids = candidate_ids[:3072]
        neg_landmark_ids = candidate_ids[3072:] + unique_neg_ids
        np.random.shuffle(neg_landmark_ids)
        
        # transform landmark id into image id
        anc_img_ids = []
        pos_img_ids = []
        neg_img_ids = []
        
        for i in range(len(pos_landmark_ids)):
            tmp_pos_ids = df[df['landmark_id'] == pos_landmark_ids[i]]['image_id'].values
            anc_img_ids.append(tmp_pos_ids[0])
            pos_img_ids.append(tmp_pos_ids[1])
            
            tmp_neg_ids = df[df['landmark_id'] == neg_landmark_ids[i]]['image_id'].values
            neg_img_ids.append(tmp_neg_ids[0])
        
        # iterator to read batch images
        for j in range(len(pos_img_ids) // batch_size):
            batch_anc_img_ids = anc_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_pos_img_ids = pos_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_neg_img_ids = neg_img_ids[j * batch_size: (j + 1) * batch_size]
            
            # get images
            anc_imgs = []
            pos_imgs = []
            neg_imgs = []
            
            # iteratively read images
            for k in range(batch_size):
                anc_path = prefix + str(batch_anc_img_ids[k]) + '.jpg'
                pos_path = prefix + str(batch_pos_img_ids[k]) + '.jpg'
                neg_path = prefix + str(batch_neg_img_ids[k]) + '.jpg'
                
                tmp_anc_img = load_img(anc_path, target_size=img_size)
                tmp_anc_img = img_to_array(tmp_anc_img)
                anc_imgs.append(tmp_anc_img)
                
                tmp_pos_img = load_img(pos_path, target_size=img_size)
                tmp_pos_img = img_to_array(tmp_pos_img)
                pos_imgs.append(tmp_pos_img)
                
                tmp_neg_img = load_img(neg_path, target_size=img_size)
                tmp_neg_img = img_to_array(tmp_neg_img)
                neg_imgs.append(tmp_neg_img)
        
            # transform list to array
            anc_imgs = np.array(anc_imgs, dtype=K.floatx()) / 255.0
            pos_imgs = np.array(pos_imgs, dtype=K.floatx()) / 255.0
            neg_imgs = np.array(neg_imgs, dtype=K.floatx()) / 255.0
            
            yield [anc_imgs, pos_imgs, neg_imgs], zeros

# %% [markdown]
# # Define Triplet Loss Model

# %%
# Define base network for triplet network
def base_net(input_shape=(224, 224, 3)):
    """ define triplet network """
    # load pre-trained VGG16 model
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=input_shape, pooling='avg')
    
    # frozen shallow layers
    vgg16.trainable = True
    
    set_trainable = False
    for layer in vgg16.layers:
        if layer.name == 'block4_conv1':
            set_trainable = True
        if set_trainable:
            layer.trainable = True
        else:
            layer.trainable = False
    
    # define sequential model
    model = Sequential(name='base_net')
    model.add(vgg16)
    model.add(Lambda(lambda x: K.l2_normalize(x, axis=1), name='l2_norm'))
    
    return model

# %%
# Define triplet network
def triplet_net(base_model, input_shape=(224, 224, 3)):
    """ function to define triplet networks """
    # define input: anchor, positive, negative
    anchor = Input(shape=input_shape, name='anchor_input')
    positive = Input(shape=input_shape, name='positive_input')
    negative = Input(shape=input_shape, name='negative_input')
    
    # extract vector represent using CNN based model
    anc_vec = base_model(anchor)
    pos_vec = base_model(positive)
    neg_vec = base_model(negative)
    
    # stack outputs
    stacks = Lambda(lambda x: K.stack(x, axis=1), name='output')([anc_vec, pos_vec, neg_vec])

    # define inputs and outputs
    inputs=[anchor, positive, negative]
    outputs = stacks
    
    # define the triplet model
    model = Model(inputs=inputs, outputs=outputs, name='triplet_net')
    
    return model

# %%
# Define triplet loss
def triplet_loss(y_true, y_pred):
    """ function to compute triplet loss
        margin is predefined coded, manually change if needed
    """
    # define triplet margin
    margin = K.constant(0.3)
    zero = K.constant(0.0)
    
    # get the prediction vector
    anchor, positive, negative = y_pred[:, 0], y_pred[:, 1], y_pred[:, 2]
    
    # compute distance
    pos_distance = K.sum(K.square(anchor - positive), axis=1)
    neg_distance = K.sum(K.square(anchor - negative), axis=1)
    
    # compute loss
    partial_loss = pos_distance - neg_distance + margin
    full_loss = K.sum(K.maximum(partial_loss, zero), axis=0)
    
    return full_loss

# %% [markdown]
# # Build Triplet Model

# %%
# For reproduciable purpose
seed = 42
K.clear_session()
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(seed)
random.seed(seed)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.set_random_seed(seed)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# Define Parameters
img_size = (224, 224, 3)  # target image size

# triplet image generator
train_generator = train_triplet_generator(train_df, batch_size=74, img_size=img_size[:2], 
                                          seed=42, prefix='./data/triplet/train/')

val_generator = val_triplet_generator(val_df, batch_size=64, img_size=img_size[:2], 
                                      seed=42, prefix='./data/triplet/validation/')

# %%
# Define triplet network model
base_model = base_net(input_shape=img_size)
base_model.summary()
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3148: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 512)               14714688
# _________________________________________________________________
# l2_norm (Lambda)             (None, 512)               0
# =================================================================
# Total params: 14,714,688
# Trainable params: 12,979,200
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
triplet_model = triplet_net(base_model=base_model, input_shape=img_size)
triplet_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# anchor_input (InputLayer)       (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# positive_input (InputLayer)     (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# negative_input (InputLayer)     (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# base_net (Sequential)           (None, 512)          14714688    anchor_input[0][0]
#                                                                  positive_input[0][0]
#                                                                  negative_input[0][0]
# __________________________________________________________________________________________________
# output (Lambda)                 (None, 3, 512)       0           base_net[1][0]
#                                                                  base_net[2][0]
#                                                                  base_net[3][0]
# ==================================================================================================
# Total params: 14,714,688
# Trainable params: 12,979,200
# Non-trainable params: 1,735,488
# __________________________________________________________________________________________________

# %% [markdown]
# # Fit Triplet Model

# %%
# define learning scheduler
def lr_schedule(epoch):
    """ Learning rate schedule """
    lr = 1e-3
    if epoch > 80:
        lr *= 6e-1
    elif epoch > 60:
        lr *= 7e-1
    elif epoch > 40:
        lr *= 8e-1
    elif epoch > 20:
        lr *= 9e-1
    print('Learning rate: ', lr)
    return lr

# define optimizer
opt = keras.optimizers.Adam(lr=lr_schedule(0))

# Create call backs
checkpoint = ModelCheckpoint(filepath='./models/vgg16-triplet(4)-ckpt.h5', 
                             monitor='val_loss', save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# compile the model
triplet_model.compile(optimizer=opt, loss=triplet_loss)
# Out:
# Learning rate:  0.001

# %%
# fit the mode
history = triplet_model.fit_generator(train_generator, steps_per_epoch=100, epochs=100, 
                                      validation_data=val_generator, validation_steps=48, 
                                      verbose=2, callbacks=callbacks)

triplet_model.save('./models/vgg16-triplet(4)-model.h5')
base_model.save('./models/vgg16-base(4)-model.h5')
pickle.dump(history.history, open('./models/vgg16-triplet(4)-history.p', 'wb'))
_ = gc.collect()
# Out:
# Epoch 1/100
# Learning rate:  0.001
#  - 88s - loss: 16.1467 - val_loss: 12.4311
# Epoch 2/100
# Learning rate:  0.001
#  - 70s - loss: 12.4514 - val_loss: 11.1563
# Epoch 3/100
# Learning rate:  0.001
#  - 70s - loss: 11.4783 - val_loss: 11.3976
# Epoch 4/100
# Learning rate:  0.001
#  - 70s - loss: 10.7648 - val_loss: 11.8255
# Epoch 5/100
# Learning rate:  0.001
#  - 70s - loss: 10.3564 - val_loss: 8.7682
# Epoch 6/100
# Learning rate:  0.001
#  - 70s - loss: 9.2388 - val_loss: 9.7603
# Epoch 7/100
# Learning rate:  0.001
#  - 70s - loss: 8.6258 - val_loss: 7.3241
# Epoch 8/100
# Learning rate:  0.001
#  - 70s - loss: 7.8777 - val_loss: 7.5711
# Epoch 9/100
# Learning rate:  0.001
#  - 70s - loss: 7.8726 - val_loss: 7.1527
# Epoch 10/100
# Learning rate:  0.001
#  - 69s - loss: 7.0019 - val_loss: 6.8801
# Epoch 11/100
# Learning rate:  0.001
#  - 69s - loss: 7.0310 - val_loss: 6.6410
# Epoch 12/100
# Learning rate:  0.001
#  - 70s - loss: 6.5357 - val_loss: 6.5281
# Epoch 13/100
# Learning rate:  0.001
#  - 70s - loss: 6.3845 - val_loss: 6.3825
# Epoch 14/100
# Learning rate:  0.001
#  - 70s - loss: 5.9649 - val_loss: 6.5684
# Epoch 15/100
# Learning rate:  0.001
#  - 70s - loss: 6.0689 - val_loss: 6.7639
# Epoch 16/100
# Learning rate:  0.001
#  - 70s - loss: 5.9446 - val_loss: 5.8517
# Epoch 17/100
# Learning rate:  0.001
#  - 70s - loss: 5.4566 - val_loss: 6.0527
# Epoch 18/100
# Learning rate:  0.001
#  - 70s - loss: 5.5432 - val_loss: 6.0507
# Epoch 19/100
# Learning rate:  0.001
#  - 70s - loss: 5.4146 - val_loss: 5.6380
# Epoch 20/100
# Learning rate:  0.001
#  - 69s - loss: 5.1804 - val_loss: 6.0403
# Epoch 21/100
# Learning rate:  0.001
#  - 69s - loss: 4.8837 - val_loss: 5.9903
# Epoch 22/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 4.9994 - val_loss: 5.4110
# Epoch 23/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 4.6605 - val_loss: 5.5610
# Epoch 24/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 4.7850 - val_loss: 5.3750
# Epoch 25/100
# Learning rate:  0.0009000000000000001
#  - 71s - loss: 4.3379 - val_loss: 5.1583
# Epoch 26/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 4.4015 - val_loss: 5.7165
# Epoch 27/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 4.5585 - val_loss: 5.0291
# Epoch 28/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 4.1594 - val_loss: 4.9574
# Epoch 29/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 4.2000 - val_loss: 5.1915
# Epoch 30/100
# Learning rate:  0.0009000000000000001
#  - 69s - loss: 4.0847 - val_loss: 4.9610
# Epoch 31/100
# Learning rate:  0.0009000000000000001
#  - 69s - loss: 3.9497 - val_loss: 4.8495
# Epoch 32/100
# Learning rate:  0.0009000000000000001
#  - 69s - loss: 3.7315 - val_loss: 4.7722
# Epoch 33/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 3.9106 - val_loss: 4.6124
# Epoch 34/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 3.7716 - val_loss: 4.5534
# Epoch 35/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 3.6118 - val_loss: 4.3076
# Epoch 36/100
# Learning rate:  0.0009000000000000001
#  - 71s - loss: 3.3523 - val_loss: 4.4375
# Epoch 37/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 3.5383 - val_loss: 4.6565
# Epoch 38/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 3.6242 - val_loss: 4.2663
# Epoch 39/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 3.7290 - val_loss: 4.3094
# Epoch 40/100
# Learning rate:  0.0009000000000000001
#  - 70s - loss: 3.3263 - val_loss: 3.9452
# Epoch 41/100
# Learning rate:  0.0009000000000000001
#  - 69s - loss: 3.2486 - val_loss: 4.2656
# Epoch 42/100
# Learning rate:  0.0008
#  - 69s - loss: 3.0624 - val_loss: 4.2337
# Epoch 43/100
# Learning rate:  0.0008
#  - 71s - loss: 3.3426 - val_loss: 4.0004
# Epoch 44/100
# Learning rate:  0.0008
#  - 71s - loss: 2.9742 - val_loss: 3.9566
# Epoch 45/100
# Learning rate:  0.0008
#  - 71s - loss: 3.0196 - val_loss: 4.1168
# Epoch 46/100
# Learning rate:  0.0008
#  - 70s - loss: 3.0658 - val_loss: 3.8976
# Epoch 47/100
# Learning rate:  0.0008
#  - 70s - loss: 2.8448 - val_loss: 3.9776
# Epoch 48/100
# Learning rate:  0.0008
#  - 70s - loss: 2.9050 - val_loss: 3.8458
# Epoch 49/100
# Learning rate:  0.0008
#  - 70s - loss: 2.9959 - val_loss: 3.8339
# Epoch 50/100
# Learning rate:  0.0008
#  - 70s - loss: 2.9938 - val_loss: 3.7447
# Epoch 51/100
# Learning rate:  0.0008
#  - 69s - loss: 2.8356 - val_loss: 3.7760
# Epoch 52/100
# Learning rate:  0.0008
#  - 69s - loss: 2.7593 - val_loss: 3.7753
# Epoch 53/100
# Learning rate:  0.0008
#  - 69s - loss: 2.6934 - val_loss: 3.5878
# Epoch 54/100
# Learning rate:  0.0008
#  - 70s - loss: 2.6336 - val_loss: 3.5627
# Epoch 55/100
# Learning rate:  0.0008
#  - 71s - loss: 2.5808 - val_loss: 3.7616
# Epoch 56/100
# Learning rate:  0.0008
#  - 70s - loss: 2.3811 - val_loss: 3.4734
# Epoch 57/100
# Learning rate:  0.0008
#  - 70s - loss: 2.5563 - val_loss: 3.6376
# Epoch 58/100
# Learning rate:  0.0008
#  - 70s - loss: 2.5529 - val_loss: 3.5888
# Epoch 59/100
# Learning rate:  0.0008
#  - 70s - loss: 2.5853 - val_loss: 4.1296
# Epoch 60/100
# Learning rate:  0.0008
#  - 70s - loss: 2.4659 - val_loss: 3.4982
# Epoch 61/100
# Learning rate:  0.0008
#  - 70s - loss: 2.3410 - val_loss: 3.4774
# Epoch 62/100
# Learning rate:  0.0007
#  - 69s - loss: 2.2998 - val_loss: 3.5893
# Epoch 63/100
# Learning rate:  0.0007
#  - 70s - loss: 2.4466 - val_loss: 3.3978
# Epoch 64/100
# Learning rate:  0.0007
#  - 70s - loss: 2.3148 - val_loss: 3.5447
# Epoch 65/100
# Learning rate:  0.0007
#  - 71s - loss: 2.4712 - val_loss: 3.4397
# Epoch 66/100
# Learning rate:  0.0007
#  - 70s - loss: 2.3178 - val_loss: 3.8725
# Epoch 67/100
# Learning rate:  0.0007
#  - 70s - loss: 2.3493 - val_loss: 3.3329
# Epoch 68/100
# Learning rate:  0.0007
#  - 70s - loss: 2.2916 - val_loss: 3.2219
# Epoch 69/100
# Learning rate:  0.0007
#  - 70s - loss: 2.1873 - val_loss: 3.3810
# Epoch 70/100
# Learning rate:  0.0007
#  - 70s - loss: 2.1236 - val_loss: 3.4401
# Epoch 71/100
# Learning rate:  0.0007
#  - 70s - loss: 2.1182 - val_loss: 3.1354
# Epoch 72/100
# Learning rate:  0.0007
#  - 70s - loss: 2.0380 - val_loss: 3.3110
# Epoch 73/100
# Learning rate:  0.0007
#  - 70s - loss: 2.0495 - val_loss: 3.5380
# Epoch 74/100
# Learning rate:  0.0007
#  - 69s - loss: 2.1989 - val_loss: 3.2168
# Epoch 75/100
# Learning rate:  0.0007
#  - 70s - loss: 2.1202 - val_loss: 3.1956
# Epoch 76/100
# Learning rate:  0.0007
#  - 70s - loss: 1.8780 - val_loss: 3.2124
# Epoch 77/100
# Learning rate:  0.0007
#  - 70s - loss: 1.9069 - val_loss: 3.0766
# Epoch 78/100
# Learning rate:  0.0007
#  - 70s - loss: 2.1241 - val_loss: 3.1389
# Epoch 79/100
# Learning rate:  0.0007
#  - 72s - loss: 2.1332 - val_loss: 3.1435
# Epoch 80/100
# Learning rate:  0.0007
#  - 70s - loss: 1.9547 - val_loss: 3.2429
# Epoch 81/100
# Learning rate:  0.0007
#  - 70s - loss: 1.8744 - val_loss: 3.2662
# Epoch 82/100
# Learning rate:  0.0006
#  - 70s - loss: 1.9759 - val_loss: 3.0193
# Epoch 83/100
# Learning rate:  0.0006
#  - 69s - loss: 1.6908 - val_loss: 3.1010
# Epoch 84/100
# Learning rate:  0.0006
#  - 69s - loss: 1.7857 - val_loss: 3.3676
# Epoch 85/100
# Learning rate:  0.0006
#  - 70s - loss: 1.7999 - val_loss: 3.2305
# Epoch 86/100
# Learning rate:  0.0006
#  - 70s - loss: 1.8725 - val_loss: 3.2858
# Epoch 87/100
# Learning rate:  0.0006
#  - 70s - loss: 1.8986 - val_loss: 3.2278
# Epoch 88/100
# Learning rate:  0.0006
#  - 70s - loss: 1.7726 - val_loss: 3.0944
# Epoch 89/100
# Learning rate:  0.0006
#  - 70s - loss: 1.5758 - val_loss: 2.9798
# Epoch 90/100
# Learning rate:  0.0006
#  - 70s - loss: 1.8172 - val_loss: 3.0967
# Epoch 91/100
# Learning rate:  0.0006
#  - 71s - loss: 1.8565 - val_loss: 3.1671
# Epoch 92/100
# Learning rate:  0.0006
#  - 70s - loss: 1.7609 - val_loss: 3.1217
# Epoch 93/100
# Learning rate:  0.0006
#  - 70s - loss: 1.8844 - val_loss: 3.2988
# Epoch 94/100
# Learning rate:  0.0006
#  - 70s - loss: 1.7335 - val_loss: 3.0652
# Epoch 95/100
# Learning rate:  0.0006
#  - 69s - loss: 1.5966 - val_loss: 3.0512
# Epoch 96/100
# Learning rate:  0.0006
#  - 70s - loss: 1.6511 - val_loss: 2.9927
# Epoch 97/100
# Learning rate:  0.0006
#  - 70s - loss: 1.6223 - val_loss: 3.0764
# Epoch 98/100
# Learning rate:  0.0006
#  - 70s - loss: 1.5908 - val_loss: 3.0879
# Epoch 99/100
# Learning rate:  0.0006
#  - 70s - loss: 1.6024 - val_loss: 2.8729
# Epoch 100/100
# Learning rate:  0.0006
#  - 70s - loss: 1.6328 - val_loss: 2.8479

# %%
# Visualize the training process
train_loss = history.history['loss']
val_loss = history.history['val_loss']

fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(train_loss, label='Training Loss')
ax.plot(val_loss, label='Validation Loss')
ax.set_title('Loss vs. Epochs', fontsize=16)
ax.set_xlabel('Epochs', fontsize=14)
ax.set_ylabel('Loss', fontsize=14)
ax.legend(fontsize=14)
ax.grid(True)
plt.show()

# %% [markdown]
# # Extract Features using Triplet Network

# %%
train_df = pd.read_csv('./data/triplet/train.csv')
val_df = pd.read_csv('./data/triplet/validation.csv')
test_df = pd.read_csv('./data/triplet/test.csv')

print('Train:\t\t', train_df.shape)
print('Validation:\t', val_df.shape)
print('Test:\t\t', test_df.shape)

print('\nTrain Landmarks:\t', len(train_df['landmark_id'].unique()))
print('Validation Landmarks:\t', len(val_df['landmark_id'].unique()))
print('Test Landmarks:\t\t', len(test_df['landmark_id'].unique()))
# Out:
# Train:		 (113783, 4)
# Validation:	 (22255, 4)
# Test:		 (22391, 4)
#
# Train Landmarks:	 14943
# Validation Landmarks:	 7674
# Test Landmarks:		 14436

# %%
# Load trained model
base_model = load_model('./models/vgg16-base(4)-model.h5')
base_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 512)               14714688
# _________________________________________________________________
# l2_norm (Lambda)             (None, 512)               0
# =================================================================
# Total params: 14,714,688
# Trainable params: 12,979,200
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
# Define train_imgs and test_imgs
train_imgs = np.zeros(shape=(len(train_df), 512), dtype=np.float32)
val_imgs = np.zeros(shape=(len(val_df), 512), dtype=np.float32)
test_imgs = np.zeros(shape=(len(test_df), 512), dtype=np.float32)

# %%
# Process training images
img_ids = train_df['image_id'].values
steps = 20000
for i in range(0, len(train_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(train_df), i + steps)
    for idx in range(start, end):
        if idx % 250 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/train/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    train_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:      20000
# ================================================================================
# Process:      40000
# ================================================================================
# Process:      60000
# ================================================================================
# Process:      80000
# ================================================================================
# Process:     100000
# ========================================================

# %%
# Process validation images
img_ids = val_df['image_id'].values
steps = 4000
for i in range(0, len(val_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(val_df), i + steps)
    for idx in range(start, end):
        if idx % 50 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/validation/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    val_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:       4000
# ================================================================================
# Process:       8000
# ================================================================================
# Process:      12000
# ================================================================================
# Process:      16000
# ================================================================================
# Process:      20000
# ==============================================

# %%
# Process test images
img_ids = test_df['image_id'].values
steps = 4000
for i in range(0, len(test_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(test_df), i + steps)
    for idx in range(start, end):
        if idx % 50 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/test/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    test_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:       4000
# ================================================================================
# Process:       8000
# ================================================================================
# Process:      12000
# ================================================================================
# Process:      16000
# ================================================================================
# Process:      20000
# ================================================

# %%
print('Train:\t\t', train_imgs.shape)
print('Validation:\t', val_imgs.shape)
print('Test:\t\t', test_imgs.shape)
# Out:
# Train:		 (113783, 512)
# Validation:	 (22255, 512)
# Test:		 (22391, 512)

# %%
# Save to disk
np.save('./data/triplet/train_triplet_vgg16(4)_features.npy', train_imgs)
np.save('./data/triplet/validation_triplet_vgg16(4)_features.npy', val_imgs)
np.save('./data/triplet/test_triplet_vgg16(4)_features.npy', test_imgs)
