# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import random, gc, keras, os, pickle

from keras import backend as K
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential, load_model, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Input, Lambda, MaxPooling2D
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load Data

# %%
train_df = pd.read_csv('./data/triplet/train.csv')
val_df = pd.read_csv('./data/triplet/validation.csv')
test_df = pd.read_csv('./data/triplet/test.csv')

print('Train:\t\t', train_df.shape)
print('Validation:\t', val_df.shape)
print('Test:\t\t', test_df.shape)

print('\nTrain Landmarks:\t', len(train_df['landmark_id'].unique()))
print('Validation Landmarks:\t', len(val_df['landmark_id'].unique()))
print('Test Landmarks:\t\t', len(test_df['landmark_id'].unique()))
# Out:
# Train:		 (113783, 4)
# Validation:	 (22255, 4)
# Test:		 (22391, 4)
#
# Train Landmarks:	 14943
# Validation Landmarks:	 7674
# Test Landmarks:		 14436

# %%
train_df.head()
# Out:
#    image_id                id  \
# 0    465272  a2ccf8ed2e969f6a
# 1     64516  e205ca7c8dd7c027
# 2    928409  4e8ab93c1620e8a3
# 3     88809  896bf928214d1ca4
# 4   1001133  375d2a153bdca926
#
#                                                  url  landmark_id
# 0  https://lh4.googleusercontent.com/-TPHkS5gzvm4...            0
# 1  https://lh3.googleusercontent.com/-V3RjsZtGpxE...            0
# 2  http://mw2.google.com/mw-panoramio/photos/medi...            0
# 3  http://lh5.ggpht.com/-Cy0l41uUaGA/R--yB8vy41I/...            0
# 4  http://lh6.ggpht.com/-UqzFpnqE9bU/S_0u1RovfdI/...            0

# %% [markdown]
# # Helper Functions

# %%
# training set triplet generator
def train_triplet_generator(df, batch_size=74, img_size=(224, 224), seed=42, 
                            prefix='./data/triplet/train/'):
    """ training set triplet generator
        it will generate 7400 triplet images in total
    """
    # get images with only one training image landmark id and the rest landmark ids
    np.random.seed(seed)
    grouped = df[['landmark_id', 'image_id']].groupby('landmark_id').count().reset_index()
    unique_neg_ids = list(grouped[grouped['image_id'] == 1]['landmark_id'].values)
    rest_ids = list(grouped[grouped['image_id'] > 1]['landmark_id'].values)
    size = 7400 * 2 - len(unique_neg_ids) 
    zeros = np.zeros((batch_size, 3, 1), dtype=K.floatx())
    
    while True:
        # get positive and negative image landmark ids
        np.random.shuffle(rest_ids)
        candidate_ids = list(np.random.choice(rest_ids, size=size, replace=False))
        pos_landmark_ids = candidate_ids[:7400]
        neg_landmark_ids = candidate_ids[7400:] + unique_neg_ids
        np.random.shuffle(neg_landmark_ids)
        
        # transform landmark id into image id
        anc_img_ids = []
        pos_img_ids = []
        neg_img_ids = []
        
        for i in range(len(pos_landmark_ids)):
            tmp_pos_ids = df[df['landmark_id'] == pos_landmark_ids[i]]['image_id'].values
            anc_img_ids.append(tmp_pos_ids[0])
            pos_img_ids.append(tmp_pos_ids[1])
            
            tmp_neg_ids = df[df['landmark_id'] == neg_landmark_ids[i]]['image_id'].values
            neg_img_ids.append(tmp_neg_ids[0])
        
        # iterator to read batch images
        for j in range(len(pos_img_ids) // batch_size):
            batch_anc_img_ids = anc_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_pos_img_ids = pos_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_neg_img_ids = neg_img_ids[j * batch_size: (j + 1) * batch_size]
            
            # get images
            anc_imgs = []
            pos_imgs = []
            neg_imgs = []
            
            # iteratively read images
            for k in range(batch_size):
                anc_path = prefix + str(batch_anc_img_ids[k]) + '.jpg'
                pos_path = prefix + str(batch_pos_img_ids[k]) + '.jpg'
                neg_path = prefix + str(batch_neg_img_ids[k]) + '.jpg'
                
                tmp_anc_img = load_img(anc_path, target_size=img_size)
                tmp_anc_img = img_to_array(tmp_anc_img)
                anc_imgs.append(tmp_anc_img)
                
                tmp_pos_img = load_img(pos_path, target_size=img_size)
                tmp_pos_img = img_to_array(tmp_pos_img)
                pos_imgs.append(tmp_pos_img)
                
                tmp_neg_img = load_img(neg_path, target_size=img_size)
                tmp_neg_img = img_to_array(tmp_neg_img)
                neg_imgs.append(tmp_neg_img)
        
            # transform list to array
            anc_imgs = np.array(anc_imgs, dtype=K.floatx()) / 255.0
            pos_imgs = np.array(pos_imgs, dtype=K.floatx()) / 255.0
            neg_imgs = np.array(neg_imgs, dtype=K.floatx()) / 255.0

            yield [anc_imgs, pos_imgs, neg_imgs], zeros

# %%
# validation set triplet generator
def val_triplet_generator(df, batch_size=128, img_size=(224, 224), 
                          seed=42, prefix='./data/triplet/validation'):
    """ validation set triplet collector """
    
     # get images with only one image landmark id and the rest landmark ids
    grouped = df[['landmark_id', 'image_id']].groupby('landmark_id').count().reset_index()
    unique_neg_ids = list(grouped[grouped['image_id'] == 1]['landmark_id'].values)
    rest_ids = list(grouped[grouped['image_id'] > 1]['landmark_id'].values)
    size = 3072 * 2 - len(unique_neg_ids) 
    zeros = np.zeros((batch_size, 3, 1), dtype=K.floatx())
    
    while True:
        # get positive and negative image landmark ids
        np.random.seed(seed)
        candidate_ids = list(np.random.choice(rest_ids, size=size, replace=False))
        pos_landmark_ids = candidate_ids[:3072]
        neg_landmark_ids = candidate_ids[3072:] + unique_neg_ids
        np.random.shuffle(neg_landmark_ids)
        
        # transform landmark id into image id
        anc_img_ids = []
        pos_img_ids = []
        neg_img_ids = []
        
        for i in range(len(pos_landmark_ids)):
            tmp_pos_ids = df[df['landmark_id'] == pos_landmark_ids[i]]['image_id'].values
            anc_img_ids.append(tmp_pos_ids[0])
            pos_img_ids.append(tmp_pos_ids[1])
            
            tmp_neg_ids = df[df['landmark_id'] == neg_landmark_ids[i]]['image_id'].values
            neg_img_ids.append(tmp_neg_ids[0])
        
        # iterator to read batch images
        for j in range(len(pos_img_ids) // batch_size):
            batch_anc_img_ids = anc_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_pos_img_ids = pos_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_neg_img_ids = neg_img_ids[j * batch_size: (j + 1) * batch_size]
            
            # get images
            anc_imgs = []
            pos_imgs = []
            neg_imgs = []
            
            # iteratively read images
            for k in range(batch_size):
                anc_path = prefix + str(batch_anc_img_ids[k]) + '.jpg'
                pos_path = prefix + str(batch_pos_img_ids[k]) + '.jpg'
                neg_path = prefix + str(batch_neg_img_ids[k]) + '.jpg'
                
                tmp_anc_img = load_img(anc_path, target_size=img_size)
                tmp_anc_img = img_to_array(tmp_anc_img)
                anc_imgs.append(tmp_anc_img)
                
                tmp_pos_img = load_img(pos_path, target_size=img_size)
                tmp_pos_img = img_to_array(tmp_pos_img)
                pos_imgs.append(tmp_pos_img)
                
                tmp_neg_img = load_img(neg_path, target_size=img_size)
                tmp_neg_img = img_to_array(tmp_neg_img)
                neg_imgs.append(tmp_neg_img)
        
            # transform list to array
            anc_imgs = np.array(anc_imgs, dtype=K.floatx()) / 255.0
            pos_imgs = np.array(pos_imgs, dtype=K.floatx()) / 255.0
            neg_imgs = np.array(neg_imgs, dtype=K.floatx()) / 255.0
            
            yield [anc_imgs, pos_imgs, neg_imgs], zeros

# %% [markdown]
# # Define Triplet Loss Model

# %%
# Define base network for triplet network
def base_net(input_shape=(224, 224, 3), trainable=False):
    """ define triplet network """
    # load pre-trained VGG16 model
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=input_shape)
    vgg16.trainable = trainable
    
    # define sequential model
    model = Sequential(name='base_net')
    model.add(vgg16)
    model.add(MaxPooling2D(pool_size=3, strides=3, padding='valid', name='max_pooling'))
    model.add(Flatten(name='flatten'))
    model.add(Dropout(rate=0.5, name='dropout'))
    model.add(Dense(512, activation=None, name='fc'))
    model.add(Lambda(lambda x: K.l2_normalize(x, axis=1), name='l2_norm'))
    
    return model

# %%
# Define triplet network
def triplet_net(base_model, input_shape=(224, 224, 3)):
    """ function to define triplet networks """
    # define input: anchor, positive, negative
    anchor = Input(shape=input_shape, name='anchor_input')
    positive = Input(shape=input_shape, name='positive_input')
    negative = Input(shape=input_shape, name='negative_input')
    
    # extract vector represent using CNN based model
    anc_vec = base_model(anchor)
    pos_vec = base_model(positive)
    neg_vec = base_model(negative)
    
    # stack outputs
    stacks = Lambda(lambda x: K.stack(x, axis=1), name='output')([anc_vec, pos_vec, neg_vec])

    # define inputs and outputs
    inputs=[anchor, positive, negative]
    outputs = stacks
    
    # define the triplet model
    model = Model(inputs=inputs, outputs=outputs, name='triplet_net')
    
    return model

# %%
# Define triplet loss
def triplet_loss(y_true, y_pred):
    """ function to compute triplet loss
        margin is predefined coded, manually change if needed
    """
    # define triplet margin
    margin = K.constant(0.3)
    zero = K.constant(0.0)
    
    # get the prediction vector
    anchor, positive, negative = y_pred[:, 0], y_pred[:, 1], y_pred[:, 2]
    
    # compute distance
    pos_distance = K.sum(K.square(anchor - positive), axis=1)
    neg_distance = K.sum(K.square(anchor - negative), axis=1)
    
    # compute loss
    partial_loss = pos_distance - neg_distance + margin
    full_loss = K.sum(K.maximum(partial_loss, zero), axis=0)
    
    return full_loss

# %% [markdown]
# # Build Triplet Model

# %%
# For reproduciable purpose
seed = 42
K.clear_session()
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(seed)
random.seed(seed)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.set_random_seed(seed)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# Define Parameters
img_size = (224, 224, 3)  # target image size

# triplet image generator
train_generator = train_triplet_generator(train_df, batch_size=74, img_size=img_size[:2], 
                                          seed=42, prefix='./data/triplet/train/')

val_generator = val_triplet_generator(val_df, batch_size=64, img_size=img_size[:2], 
                                      seed=42, prefix='./data/triplet/validation/')

# %%
# Define triplet network model
base_model = base_net(input_shape=img_size, trainable=False)
base_model.summary()
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3148: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# max_pooling (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# fc (Dense)                   (None, 512)               1049088
# _________________________________________________________________
# l2_norm (Lambda)             (None, 512)               0
# =================================================================
# Total params: 15,763,776
# Trainable params: 1,049,088
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
triplet_model = triplet_net(base_model=base_model, input_shape=img_size)
triplet_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# anchor_input (InputLayer)       (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# positive_input (InputLayer)     (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# negative_input (InputLayer)     (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# base_net (Sequential)           (None, 512)          15763776    anchor_input[0][0]
#                                                                  positive_input[0][0]
#                                                                  negative_input[0][0]
# __________________________________________________________________________________________________
# output (Lambda)                 (None, 3, 512)       0           base_net[1][0]
#                                                                  base_net[2][0]
#                                                                  base_net[3][0]
# ==================================================================================================
# Total params: 15,763,776
# Trainable params: 1,049,088
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %% [markdown]
# # Fit Triplet Model

# %%
# define learning scheduler
def lr_schedule(epoch):
    """ Learning rate schedule """
    lr = 1e-3
    if epoch > 80:
        lr *= 2e-1
    elif epoch > 60:
        lr *= 4e-1
    elif epoch > 40:
        lr *= 6e-1
    elif epoch > 20:
        lr *= 8e-1
    print('Learning rate: ', lr)
    return lr

# define optimizer
opt = keras.optimizers.Adam(lr=lr_schedule(0))

# Create call backs
checkpoint = ModelCheckpoint(filepath='./models/vgg16-triplet(2)-ckpt.h5', 
                             monitor='val_loss', save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# compile the model
triplet_model.compile(optimizer=opt, loss=triplet_loss)
# Out:
# Learning rate:  0.001

# %%
# fit the mode
history = triplet_model.fit_generator(train_generator, steps_per_epoch=100, epochs=100, 
                                      validation_data=val_generator, validation_steps=48, 
                                      verbose=2, callbacks=callbacks)

triplet_model.save('./models/vgg16-triplet(2)-model.h5')
base_model.save('./models/vgg16-base(2)-model.h5')
pickle.dump(history.history, open('./models/vgg16-triplet(2)-history.p', 'wb'))
_ = gc.collect()
# Out:
# Epoch 1/100
# Learning rate:  0.001
#  - 72s - loss: 10.6401 - val_loss: 6.4238
# Epoch 2/100
# Learning rate:  0.001
#  - 55s - loss: 7.0316 - val_loss: 5.3837
# Epoch 3/100
# Learning rate:  0.001
#  - 55s - loss: 6.2526 - val_loss: 4.8987
# Epoch 4/100
# Learning rate:  0.001
#  - 55s - loss: 6.2575 - val_loss: 4.8776
# Epoch 5/100
# Learning rate:  0.001
#  - 55s - loss: 5.6078 - val_loss: 4.6333
# Epoch 6/100
# Learning rate:  0.001
#  - 55s - loss: 5.4145 - val_loss: 4.5081
# Epoch 7/100
# Learning rate:  0.001
#  - 55s - loss: 5.0891 - val_loss: 4.5664
# Epoch 8/100
# Learning rate:  0.001
#  - 55s - loss: 5.2433 - val_loss: 4.3968
# Epoch 9/100
# Learning rate:  0.001
#  - 55s - loss: 5.0603 - val_loss: 4.3321
# Epoch 10/100
# Learning rate:  0.001
#  - 55s - loss: 4.8392 - val_loss: 4.2445
# Epoch 11/100
# Learning rate:  0.001
#  - 55s - loss: 4.7059 - val_loss: 4.3176
# Epoch 12/100
# Learning rate:  0.001
#  - 55s - loss: 4.7552 - val_loss: 4.2298
# Epoch 13/100
# Learning rate:  0.001
#  - 55s - loss: 4.6361 - val_loss: 4.1420
# Epoch 14/100
# Learning rate:  0.001
#  - 55s - loss: 4.6066 - val_loss: 4.1966
# Epoch 15/100
# Learning rate:  0.001
#  - 55s - loss: 4.3423 - val_loss: 4.0178
# Epoch 16/100
# Learning rate:  0.001
#  - 55s - loss: 4.4501 - val_loss: 3.8727
# Epoch 17/100
# Learning rate:  0.001
#  - 55s - loss: 4.2058 - val_loss: 4.0164
# Epoch 18/100
# Learning rate:  0.001
#  - 55s - loss: 4.3042 - val_loss: 3.9550
# Epoch 19/100
# Learning rate:  0.001
#  - 55s - loss: 3.9849 - val_loss: 3.8952
# Epoch 20/100
# Learning rate:  0.001
#  - 55s - loss: 4.4079 - val_loss: 3.8864
# Epoch 21/100
# Learning rate:  0.001
#  - 55s - loss: 4.0850 - val_loss: 3.9419
# Epoch 22/100
# Learning rate:  0.0008
#  - 55s - loss: 4.2333 - val_loss: 3.8036
# Epoch 23/100
# Learning rate:  0.0008
#  - 55s - loss: 4.0457 - val_loss: 3.8370
# Epoch 24/100
# Learning rate:  0.0008
#  - 55s - loss: 4.1788 - val_loss: 3.7236
# Epoch 25/100
# Learning rate:  0.0008
#  - 55s - loss: 3.9540 - val_loss: 3.7676
# Epoch 26/100
# Learning rate:  0.0008
#  - 55s - loss: 3.8437 - val_loss: 3.7908
# Epoch 27/100
# Learning rate:  0.0008
#  - 55s - loss: 3.9310 - val_loss: 3.7634
# Epoch 28/100
# Learning rate:  0.0008
#  - 55s - loss: 3.7838 - val_loss: 3.7771
# Epoch 29/100
# Learning rate:  0.0008
#  - 57s - loss: 3.8399 - val_loss: 3.6822
# Epoch 30/100
# Learning rate:  0.0008
#  - 56s - loss: 3.7966 - val_loss: 3.6706
# Epoch 31/100
# Learning rate:  0.0008
#  - 55s - loss: 3.8214 - val_loss: 3.6004
# Epoch 32/100
# Learning rate:  0.0008
#  - 55s - loss: 3.6991 - val_loss: 3.6477
# Epoch 33/100
# Learning rate:  0.0008
#  - 55s - loss: 3.9525 - val_loss: 3.6605
# Epoch 34/100
# Learning rate:  0.0008
#  - 55s - loss: 3.6946 - val_loss: 3.6417
# Epoch 35/100
# Learning rate:  0.0008
#  - 55s - loss: 3.6876 - val_loss: 3.6793
# Epoch 36/100
# Learning rate:  0.0008
#  - 55s - loss: 3.8889 - val_loss: 3.7335
# Epoch 37/100
# Learning rate:  0.0008
#  - 55s - loss: 3.6006 - val_loss: 3.7259
# Epoch 38/100
# Learning rate:  0.0008
#  - 55s - loss: 3.6475 - val_loss: 3.6827
# Epoch 39/100
# Learning rate:  0.0008
#  - 58s - loss: 3.8928 - val_loss: 3.6611
# Epoch 40/100
# Learning rate:  0.0008
#  - 55s - loss: 3.6397 - val_loss: 3.5303
# Epoch 41/100
# Learning rate:  0.0008
#  - 55s - loss: 3.6381 - val_loss: 3.5997
# Epoch 42/100
# Learning rate:  0.0006
#  - 55s - loss: 3.4826 - val_loss: 3.6325
# Epoch 43/100
# Learning rate:  0.0006
#  - 55s - loss: 3.4683 - val_loss: 3.5053
# Epoch 44/100
# Learning rate:  0.0006
#  - 55s - loss: 3.6189 - val_loss: 3.4481
# Epoch 45/100
# Learning rate:  0.0006
#  - 55s - loss: 3.6135 - val_loss: 3.5062
# Epoch 46/100
# Learning rate:  0.0006
#  - 55s - loss: 3.2442 - val_loss: 3.5108
# Epoch 47/100
# Learning rate:  0.0006
#  - 55s - loss: 3.4468 - val_loss: 3.5932
# Epoch 48/100
# Learning rate:  0.0006
#  - 55s - loss: 3.4175 - val_loss: 3.5749
# Epoch 49/100
# Learning rate:  0.0006
#  - 55s - loss: 3.5511 - val_loss: 3.4138
# Epoch 50/100
# Learning rate:  0.0006
#  - 55s - loss: 3.4485 - val_loss: 3.5626
# Epoch 51/100
# Learning rate:  0.0006
#  - 55s - loss: 3.2200 - val_loss: 3.5746
# Epoch 52/100
# Learning rate:  0.0006
#  - 55s - loss: 3.6206 - val_loss: 3.5243
# Epoch 53/100
# Learning rate:  0.0006
#  - 56s - loss: 3.3651 - val_loss: 3.5602
# Epoch 54/100
# Learning rate:  0.0006
#  - 56s - loss: 3.4496 - val_loss: 3.5280
# Epoch 55/100
# Learning rate:  0.0006
#  - 55s - loss: 3.2735 - val_loss: 3.5181
# Epoch 56/100
# Learning rate:  0.0006
#  - 55s - loss: 3.2697 - val_loss: 3.4472
# Epoch 57/100
# Learning rate:  0.0006
#  - 55s - loss: 3.2279 - val_loss: 3.4594
# Epoch 58/100
# Learning rate:  0.0006
#  - 55s - loss: 3.2025 - val_loss: 3.4707
# Epoch 59/100
# Learning rate:  0.0006
#  - 55s - loss: 3.1461 - val_loss: 3.4826
# Epoch 60/100
# Learning rate:  0.0006
#  - 55s - loss: 3.2884 - val_loss: 3.4184
# Epoch 61/100
# Learning rate:  0.0006
#  - 55s - loss: 3.1942 - val_loss: 3.4556
# Epoch 62/100
# Learning rate:  0.0004
#  - 55s - loss: 3.1218 - val_loss: 3.3956
# Epoch 63/100
# Learning rate:  0.0004
#  - 55s - loss: 3.0382 - val_loss: 3.5263
# Epoch 64/100
# Learning rate:  0.0004
#  - 55s - loss: 3.1994 - val_loss: 3.4790
# Epoch 65/100
# Learning rate:  0.0004
#  - 55s - loss: 3.2328 - val_loss: 3.4877
# Epoch 66/100
# Learning rate:  0.0004
#  - 55s - loss: 3.1423 - val_loss: 3.4806
# Epoch 67/100
# Learning rate:  0.0004
#  - 55s - loss: 3.2729 - val_loss: 3.4315
# Epoch 68/100
# Learning rate:  0.0004
#  - 55s - loss: 3.0404 - val_loss: 3.4299
# Epoch 69/100
# Learning rate:  0.0004
#  - 55s - loss: 3.0811 - val_loss: 3.4393
# Epoch 70/100
# Learning rate:  0.0004
#  - 55s - loss: 3.1053 - val_loss: 3.4306
# Epoch 71/100
# Learning rate:  0.0004
#  - 55s - loss: 3.0044 - val_loss: 3.4136
# Epoch 72/100
# Learning rate:  0.0004
#  - 55s - loss: 3.1339 - val_loss: 3.3913
# Epoch 73/100
# Learning rate:  0.0004
#  - 55s - loss: 2.9847 - val_loss: 3.3677
# Epoch 74/100
# Learning rate:  0.0004
#  - 55s - loss: 2.9475 - val_loss: 3.3988
# Epoch 75/100
# Learning rate:  0.0004
#  - 55s - loss: 2.9634 - val_loss: 3.3947
# Epoch 76/100
# Learning rate:  0.0004
#  - 55s - loss: 3.0286 - val_loss: 3.3988
# Epoch 77/100
# Learning rate:  0.0004
#  - 55s - loss: 3.0728 - val_loss: 3.3598
# Epoch 78/100
# Learning rate:  0.0004
#  - 55s - loss: 2.9944 - val_loss: 3.3845
# Epoch 79/100
# Learning rate:  0.0004
#  - 55s - loss: 3.0631 - val_loss: 3.3926
# Epoch 80/100
# Learning rate:  0.0004
#  - 55s - loss: 3.0980 - val_loss: 3.2826
# Epoch 81/100
# Learning rate:  0.0004
#  - 55s - loss: 2.9300 - val_loss: 3.3146
# Epoch 82/100
# Learning rate:  0.0002
#  - 55s - loss: 2.9397 - val_loss: 3.3686
# Epoch 83/100
# Learning rate:  0.0002
#  - 55s - loss: 2.9374 - val_loss: 3.3701
# Epoch 84/100
# Learning rate:  0.0002
#  - 58s - loss: 2.8718 - val_loss: 3.3795
# Epoch 85/100
# Learning rate:  0.0002
#  - 55s - loss: 2.7405 - val_loss: 3.4078
# Epoch 86/100
# Learning rate:  0.0002
#  - 56s - loss: 2.8751 - val_loss: 3.4042
# Epoch 87/100
# Learning rate:  0.0002
#  - 55s - loss: 2.9437 - val_loss: 3.3767
# Epoch 88/100
# Learning rate:  0.0002
#  - 55s - loss: 2.7775 - val_loss: 3.3702
# Epoch 89/100
# Learning rate:  0.0002
#  - 55s - loss: 2.8479 - val_loss: 3.3321
# Epoch 90/100
# Learning rate:  0.0002
#  - 55s - loss: 2.8833 - val_loss: 3.3183
# Epoch 91/100
# Learning rate:  0.0002
#  - 55s - loss: 2.9702 - val_loss: 3.3510
# Epoch 92/100
# Learning rate:  0.0002
#  - 55s - loss: 2.7510 - val_loss: 3.3642
# Epoch 93/100
# Learning rate:  0.0002
#  - 56s - loss: 2.7408 - val_loss: 3.4021
# Epoch 94/100
# Learning rate:  0.0002
#  - 55s - loss: 2.9432 - val_loss: 3.3231
# Epoch 95/100
# Learning rate:  0.0002
#  - 55s - loss: 3.0457 - val_loss: 3.3144
# Epoch 96/100
# Learning rate:  0.0002
#  - 55s - loss: 2.6723 - val_loss: 3.3357
# Epoch 97/100
# Learning rate:  0.0002
#  - 55s - loss: 2.8164 - val_loss: 3.3725
# Epoch 98/100
# Learning rate:  0.0002
#  - 55s - loss: 2.6844 - val_loss: 3.3881
# Epoch 99/100
# Learning rate:  0.0002
#  - 55s - loss: 2.6091 - val_loss: 3.3900
# Epoch 100/100
# Learning rate:  0.0002
#  - 57s - loss: 2.8206 - val_loss: 3.3991

# %%
# Visualize the training process
train_loss = history.history['loss']
val_loss = history.history['val_loss']

fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(train_loss, label='Training Loss')
ax.plot(val_loss, label='Validation Loss')
ax.set_title('Loss vs. Epochs', fontsize=16)
ax.set_xlabel('Epochs', fontsize=14)
ax.set_ylabel('Loss', fontsize=14)
ax.legend(fontsize=14)
ax.grid(True)
plt.show()

# %% [markdown]
# # Extract Features using Triplet Network

# %%
train_df = pd.read_csv('./data/triplet/train.csv')
val_df = pd.read_csv('./data/triplet/validation.csv')
test_df = pd.read_csv('./data/triplet/test.csv')

print('Train:\t\t', train_df.shape)
print('Validation:\t', val_df.shape)
print('Test:\t\t', test_df.shape)

print('\nTrain Landmarks:\t', len(train_df['landmark_id'].unique()))
print('Validation Landmarks:\t', len(val_df['landmark_id'].unique()))
print('Test Landmarks:\t\t', len(test_df['landmark_id'].unique()))
# Out:
# Train:		 (113783, 4)
# Validation:	 (22255, 4)
# Test:		 (22391, 4)
#
# Train Landmarks:	 14943
# Validation Landmarks:	 7674
# Test Landmarks:		 14436

# %%
# Load trained model
base_model = load_model('./models/vgg16-base(2)-model.h5')
base_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# max_pooling (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# fc (Dense)                   (None, 512)               1049088
# _________________________________________________________________
# l2_norm (Lambda)             (None, 512)               0
# =================================================================
# Total params: 15,763,776
# Trainable params: 15,763,776
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define train_imgs and test_imgs
train_imgs = np.zeros(shape=(len(train_df), 512), dtype=np.float32)
val_imgs = np.zeros(shape=(len(val_df), 512), dtype=np.float32)
test_imgs = np.zeros(shape=(len(test_df), 512), dtype=np.float32)

# %%
# Process training images
img_ids = train_df['image_id'].values
steps = 20000
for i in range(0, len(train_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(train_df), i + steps)
    for idx in range(start, end):
        if idx % 250 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/train/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    train_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:      20000
# ================================================================================
# Process:      40000
# ================================================================================
# Process:      60000
# ================================================================================
# Process:      80000
# ================================================================================
# Process:     100000
# ========================================================

# %%
# Process validation images
img_ids = val_df['image_id'].values
steps = 4000
for i in range(0, len(val_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(val_df), i + steps)
    for idx in range(start, end):
        if idx % 50 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/validation/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    val_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:       4000
# ================================================================================
# Process:       8000
# ================================================================================
# Process:      12000
# ================================================================================
# Process:      16000
# ================================================================================
# Process:      20000
# ==============================================

# %%
# Process test images
img_ids = test_df['image_id'].values
steps = 4000
for i in range(0, len(test_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(test_df), i + steps)
    for idx in range(start, end):
        if idx % 50 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/test/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    test_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:       4000
# ================================================================================
# Process:       8000
# ================================================================================
# Process:      12000
# ================================================================================
# Process:      16000
# ================================================================================
# Process:      20000
# ================================================

# %%
print('Train:\t\t', train_imgs.shape)
print('Validation:\t', val_imgs.shape)
print('Test:\t\t', test_imgs.shape)
# Out:
# Train:		 (113783, 512)
# Validation:	 (22255, 512)
# Test:		 (22391, 512)

# %%
# Save to disk
np.save('./data/triplet/train_triplet_vgg16(2)_features.npy', train_imgs)
np.save('./data/triplet/validation_triplet_vgg16(2)_features.npy', val_imgs)
np.save('./data/triplet/test_triplet_vgg16(2)_features.npy', test_imgs)
