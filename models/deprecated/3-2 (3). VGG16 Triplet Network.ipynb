# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import random, gc, keras, os, pickle

from keras import backend as K
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential, load_model, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Input, Lambda, MaxPooling2D
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load Data

# %%
train_df = pd.read_csv('./data/triplet/train.csv')
val_df = pd.read_csv('./data/triplet/validation.csv')
test_df = pd.read_csv('./data/triplet/test.csv')

print('Train:\t\t', train_df.shape)
print('Validation:\t', val_df.shape)
print('Test:\t\t', test_df.shape)

print('\nTrain Landmarks:\t', len(train_df['landmark_id'].unique()))
print('Validation Landmarks:\t', len(val_df['landmark_id'].unique()))
print('Test Landmarks:\t\t', len(test_df['landmark_id'].unique()))
# Out:
# Train:		 (113783, 4)
# Validation:	 (22255, 4)
# Test:		 (22391, 4)
#
# Train Landmarks:	 14943
# Validation Landmarks:	 7674
# Test Landmarks:		 14436

# %%
train_df.head()
# Out:
#    image_id                id  \
# 0    465272  a2ccf8ed2e969f6a
# 1     64516  e205ca7c8dd7c027
# 2    928409  4e8ab93c1620e8a3
# 3     88809  896bf928214d1ca4
# 4   1001133  375d2a153bdca926
#
#                                                  url  landmark_id
# 0  https://lh4.googleusercontent.com/-TPHkS5gzvm4...            0
# 1  https://lh3.googleusercontent.com/-V3RjsZtGpxE...            0
# 2  http://mw2.google.com/mw-panoramio/photos/medi...            0
# 3  http://lh5.ggpht.com/-Cy0l41uUaGA/R--yB8vy41I/...            0
# 4  http://lh6.ggpht.com/-UqzFpnqE9bU/S_0u1RovfdI/...            0

# %% [markdown]
# # Helper Functions

# %%
# training set triplet generator
def train_triplet_generator(df, batch_size=74, img_size=(224, 224), seed=42, 
                            prefix='./data/triplet/train/'):
    """ training set triplet generator
        it will generate 7400 triplet images in total
    """
    # get images with only one training image landmark id and the rest landmark ids
    np.random.seed(seed)
    grouped = df[['landmark_id', 'image_id']].groupby('landmark_id').count().reset_index()
    unique_neg_ids = list(grouped[grouped['image_id'] == 1]['landmark_id'].values)
    rest_ids = list(grouped[grouped['image_id'] > 1]['landmark_id'].values)
    size = 7400 * 2 - len(unique_neg_ids) 
    zeros = np.zeros((batch_size, 3, 1), dtype=K.floatx())
    
    while True:
        # get positive and negative image landmark ids
        np.random.shuffle(rest_ids)
        candidate_ids = list(np.random.choice(rest_ids, size=size, replace=False))
        pos_landmark_ids = candidate_ids[:7400]
        neg_landmark_ids = candidate_ids[7400:] + unique_neg_ids
        np.random.shuffle(neg_landmark_ids)
        
        # transform landmark id into image id
        anc_img_ids = []
        pos_img_ids = []
        neg_img_ids = []
        
        for i in range(len(pos_landmark_ids)):
            tmp_pos_ids = df[df['landmark_id'] == pos_landmark_ids[i]]['image_id'].values
            anc_img_ids.append(tmp_pos_ids[0])
            pos_img_ids.append(tmp_pos_ids[1])
            
            tmp_neg_ids = df[df['landmark_id'] == neg_landmark_ids[i]]['image_id'].values
            neg_img_ids.append(tmp_neg_ids[0])
        
        # iterator to read batch images
        for j in range(len(pos_img_ids) // batch_size):
            batch_anc_img_ids = anc_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_pos_img_ids = pos_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_neg_img_ids = neg_img_ids[j * batch_size: (j + 1) * batch_size]
            
            # get images
            anc_imgs = []
            pos_imgs = []
            neg_imgs = []
            
            # iteratively read images
            for k in range(batch_size):
                anc_path = prefix + str(batch_anc_img_ids[k]) + '.jpg'
                pos_path = prefix + str(batch_pos_img_ids[k]) + '.jpg'
                neg_path = prefix + str(batch_neg_img_ids[k]) + '.jpg'
                
                tmp_anc_img = load_img(anc_path, target_size=img_size)
                tmp_anc_img = img_to_array(tmp_anc_img)
                anc_imgs.append(tmp_anc_img)
                
                tmp_pos_img = load_img(pos_path, target_size=img_size)
                tmp_pos_img = img_to_array(tmp_pos_img)
                pos_imgs.append(tmp_pos_img)
                
                tmp_neg_img = load_img(neg_path, target_size=img_size)
                tmp_neg_img = img_to_array(tmp_neg_img)
                neg_imgs.append(tmp_neg_img)
        
            # transform list to array
            anc_imgs = np.array(anc_imgs, dtype=K.floatx()) / 255.0
            pos_imgs = np.array(pos_imgs, dtype=K.floatx()) / 255.0
            neg_imgs = np.array(neg_imgs, dtype=K.floatx()) / 255.0

            yield [anc_imgs, pos_imgs, neg_imgs], zeros

# %%
# validation set triplet generator
def val_triplet_generator(df, batch_size=128, img_size=(224, 224), 
                          seed=42, prefix='./data/triplet/validation'):
    """ validation set triplet collector """
    
     # get images with only one image landmark id and the rest landmark ids
    grouped = df[['landmark_id', 'image_id']].groupby('landmark_id').count().reset_index()
    unique_neg_ids = list(grouped[grouped['image_id'] == 1]['landmark_id'].values)
    rest_ids = list(grouped[grouped['image_id'] > 1]['landmark_id'].values)
    size = 3072 * 2 - len(unique_neg_ids) 
    zeros = np.zeros((batch_size, 3, 1), dtype=K.floatx())
    
    while True:
        # get positive and negative image landmark ids
        np.random.seed(seed)
        candidate_ids = list(np.random.choice(rest_ids, size=size, replace=False))
        pos_landmark_ids = candidate_ids[:3072]
        neg_landmark_ids = candidate_ids[3072:] + unique_neg_ids
        np.random.shuffle(neg_landmark_ids)
        
        # transform landmark id into image id
        anc_img_ids = []
        pos_img_ids = []
        neg_img_ids = []
        
        for i in range(len(pos_landmark_ids)):
            tmp_pos_ids = df[df['landmark_id'] == pos_landmark_ids[i]]['image_id'].values
            anc_img_ids.append(tmp_pos_ids[0])
            pos_img_ids.append(tmp_pos_ids[1])
            
            tmp_neg_ids = df[df['landmark_id'] == neg_landmark_ids[i]]['image_id'].values
            neg_img_ids.append(tmp_neg_ids[0])
        
        # iterator to read batch images
        for j in range(len(pos_img_ids) // batch_size):
            batch_anc_img_ids = anc_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_pos_img_ids = pos_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_neg_img_ids = neg_img_ids[j * batch_size: (j + 1) * batch_size]
            
            # get images
            anc_imgs = []
            pos_imgs = []
            neg_imgs = []
            
            # iteratively read images
            for k in range(batch_size):
                anc_path = prefix + str(batch_anc_img_ids[k]) + '.jpg'
                pos_path = prefix + str(batch_pos_img_ids[k]) + '.jpg'
                neg_path = prefix + str(batch_neg_img_ids[k]) + '.jpg'
                
                tmp_anc_img = load_img(anc_path, target_size=img_size)
                tmp_anc_img = img_to_array(tmp_anc_img)
                anc_imgs.append(tmp_anc_img)
                
                tmp_pos_img = load_img(pos_path, target_size=img_size)
                tmp_pos_img = img_to_array(tmp_pos_img)
                pos_imgs.append(tmp_pos_img)
                
                tmp_neg_img = load_img(neg_path, target_size=img_size)
                tmp_neg_img = img_to_array(tmp_neg_img)
                neg_imgs.append(tmp_neg_img)
        
            # transform list to array
            anc_imgs = np.array(anc_imgs, dtype=K.floatx()) / 255.0
            pos_imgs = np.array(pos_imgs, dtype=K.floatx()) / 255.0
            neg_imgs = np.array(neg_imgs, dtype=K.floatx()) / 255.0
            
            yield [anc_imgs, pos_imgs, neg_imgs], zeros

# %% [markdown]
# # Define Triplet Loss Model

# %%
# Define base network for triplet network
def base_net(input_shape=(224, 224, 3), trainable=False):
    """ define triplet network """
    # load pre-trained VGG16 model
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=input_shape)
    vgg16.trainable = trainable
    
    # define sequential model
    model = Sequential(name='base_net')
    model.add(vgg16)
    model.add(MaxPooling2D(pool_size=3, strides=2, padding='valid', name='max_pooling'))
    model.add(Flatten(name='flatten'))
    model.add(Dropout(rate=0.5, name='dropout'))
    model.add(Dense(512, activation=None, name='fc'))
    model.add(Lambda(lambda x: K.l2_normalize(x, axis=1), name='l2_norm'))
    
    return model

# %%
# Define triplet network
def triplet_net(base_model, input_shape=(224, 224, 3)):
    """ function to define triplet networks """
    # define input: anchor, positive, negative
    anchor = Input(shape=input_shape, name='anchor_input')
    positive = Input(shape=input_shape, name='positive_input')
    negative = Input(shape=input_shape, name='negative_input')
    
    # extract vector represent using CNN based model
    anc_vec = base_model(anchor)
    pos_vec = base_model(positive)
    neg_vec = base_model(negative)
    
    # stack outputs
    stacks = Lambda(lambda x: K.stack(x, axis=1), name='output')([anc_vec, pos_vec, neg_vec])

    # define inputs and outputs
    inputs=[anchor, positive, negative]
    outputs = stacks
    
    # define the triplet model
    model = Model(inputs=inputs, outputs=outputs, name='triplet_net')
    
    return model

# %%
# Define triplet loss
def triplet_loss(y_true, y_pred):
    """ function to compute triplet loss
        margin is predefined coded, manually change if needed
    """
    # define triplet margin
    margin = K.constant(0.3)
    zero = K.constant(0.0)
    
    # get the prediction vector
    anchor, positive, negative = y_pred[:, 0], y_pred[:, 1], y_pred[:, 2]
    
    # compute distance
    pos_distance = K.sum(K.square(anchor - positive), axis=1)
    neg_distance = K.sum(K.square(anchor - negative), axis=1)
    
    # compute loss
    partial_loss = pos_distance - neg_distance + margin
    full_loss = K.sum(K.maximum(partial_loss, zero), axis=0)
    
    return full_loss

# %% [markdown]
# # Build Triplet Model

# %%
# For reproduciable purpose
seed = 42
K.clear_session()
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(seed)
random.seed(seed)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.set_random_seed(seed)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# Define Parameters
img_size = (224, 224, 3)  # target image size

# triplet image generator
train_generator = train_triplet_generator(train_df, batch_size=74, img_size=img_size[:2], 
                                          seed=42, prefix='./data/triplet/train/')

val_generator = val_triplet_generator(val_df, batch_size=64, img_size=img_size[:2], 
                                      seed=42, prefix='./data/triplet/validation/')

# %%
# Define triplet network model
base_model = base_net(input_shape=img_size, trainable=False)
base_model.summary()
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3148: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# max_pooling (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4608)              0
# _________________________________________________________________
# fc (Dense)                   (None, 512)               2359808
# _________________________________________________________________
# l2_norm (Lambda)             (None, 512)               0
# =================================================================
# Total params: 17,074,496
# Trainable params: 2,359,808
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
triplet_model = triplet_net(base_model=base_model, input_shape=img_size)
triplet_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# anchor_input (InputLayer)       (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# positive_input (InputLayer)     (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# negative_input (InputLayer)     (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# base_net (Sequential)           (None, 512)          17074496    anchor_input[0][0]
#                                                                  positive_input[0][0]
#                                                                  negative_input[0][0]
# __________________________________________________________________________________________________
# output (Lambda)                 (None, 3, 512)       0           base_net[1][0]
#                                                                  base_net[2][0]
#                                                                  base_net[3][0]
# ==================================================================================================
# Total params: 17,074,496
# Trainable params: 2,359,808
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %% [markdown]
# # Fit Triplet Model

# %%
# define learning scheduler
def lr_schedule(epoch):
    """ Learning rate schedule """
    lr = 1e-3
    if epoch > 80:
        lr *= 6e-1
    elif epoch > 60:
        lr *= 7e-1
    elif epoch > 40:
        lr *= 8e-1
    elif epoch > 20:
        lr *= 9e-1
    print('Learning rate: ', lr)
    return lr

# define optimizer
opt = keras.optimizers.Adam(lr=lr_schedule(0))

# Create call backs
checkpoint = ModelCheckpoint(filepath='./models/vgg16-triplet(3)-ckpt.h5', 
                             monitor='val_loss', save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# compile the model
triplet_model.compile(optimizer=opt, loss=triplet_loss)
# Out:
# Learning rate:  0.001

# %%
# fit the mode
history = triplet_model.fit_generator(train_generator, steps_per_epoch=100, epochs=100, 
                                      validation_data=val_generator, validation_steps=48, 
                                      verbose=2, callbacks=callbacks)

triplet_model.save('./models/vgg16-triplet(3)-model.h5')
base_model.save('./models/vgg16-base(3)-model.h5')
pickle.dump(history.history, open('./models/vgg16-triplet(3)-history.p', 'wb'))
_ = gc.collect()
# Out:
# Epoch 1/100
# Learning rate:  0.001
#  - 97s - loss: 8.8279 - val_loss: 5.9877
# Epoch 2/100
# Learning rate:  0.001
#  - 56s - loss: 5.9733 - val_loss: 5.0502
# Epoch 3/100
# Learning rate:  0.001
#  - 56s - loss: 5.3182 - val_loss: 4.6210
# Epoch 4/100
# Learning rate:  0.001
#  - 55s - loss: 5.2896 - val_loss: 4.5458
# Epoch 5/100
# Learning rate:  0.001
#  - 55s - loss: 4.7788 - val_loss: 4.2937
# Epoch 6/100
# Learning rate:  0.001
#  - 55s - loss: 4.3835 - val_loss: 4.2827
# Epoch 7/100
# Learning rate:  0.001
#  - 55s - loss: 4.3416 - val_loss: 4.2512
# Epoch 8/100
# Learning rate:  0.001
#  - 55s - loss: 4.1957 - val_loss: 3.9578
# Epoch 9/100
# Learning rate:  0.001
#  - 55s - loss: 4.0059 - val_loss: 3.9925
# Epoch 10/100
# Learning rate:  0.001
#  - 55s - loss: 3.9868 - val_loss: 3.9969
# Epoch 11/100
# Learning rate:  0.001
#  - 55s - loss: 3.9740 - val_loss: 4.0169
# Epoch 12/100
# Learning rate:  0.001
#  - 57s - loss: 3.7598 - val_loss: 3.9135
# Epoch 13/100
# Learning rate:  0.001
#  - 55s - loss: 3.6983 - val_loss: 3.8421
# Epoch 14/100
# Learning rate:  0.001
#  - 57s - loss: 3.4991 - val_loss: 3.8903
# Epoch 15/100
# Learning rate:  0.001
#  - 58s - loss: 3.3008 - val_loss: 3.9158
# Epoch 16/100
# Learning rate:  0.001
#  - 55s - loss: 3.5773 - val_loss: 3.6448
# Epoch 17/100
# Learning rate:  0.001
#  - 57s - loss: 3.2936 - val_loss: 3.8205
# Epoch 18/100
# Learning rate:  0.001
#  - 55s - loss: 3.5365 - val_loss: 3.7763
# Epoch 19/100
# Learning rate:  0.001
#  - 55s - loss: 3.1053 - val_loss: 3.7258
# Epoch 20/100
# Learning rate:  0.001
#  - 55s - loss: 3.1777 - val_loss: 3.6545
# Epoch 21/100
# Learning rate:  0.001
#  - 55s - loss: 2.9818 - val_loss: 3.6806
# Epoch 22/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 3.1279 - val_loss: 3.6928
# Epoch 23/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 3.0339 - val_loss: 3.6904
# Epoch 24/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 3.0634 - val_loss: 3.5837
# Epoch 25/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.9510 - val_loss: 3.5008
# Epoch 26/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.9236 - val_loss: 3.5474
# Epoch 27/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.9146 - val_loss: 3.6917
# Epoch 28/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.7144 - val_loss: 3.5247
# Epoch 29/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 3.0671 - val_loss: 3.5429
# Epoch 30/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.7068 - val_loss: 3.5396
# Epoch 31/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.8688 - val_loss: 3.5519
# Epoch 32/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.7349 - val_loss: 3.5610
# Epoch 33/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.7748 - val_loss: 3.3594
# Epoch 34/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.6829 - val_loss: 3.4556
# Epoch 35/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.7437 - val_loss: 3.4579
# Epoch 36/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.8984 - val_loss: 3.4755
# Epoch 37/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.7964 - val_loss: 3.5742
# Epoch 38/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.6511 - val_loss: 3.3996
# Epoch 39/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.8513 - val_loss: 3.4206
# Epoch 40/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.6077 - val_loss: 3.4556
# Epoch 41/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 2.5435 - val_loss: 3.3945
# Epoch 42/100
# Learning rate:  0.0008
#  - 55s - loss: 2.5137 - val_loss: 3.4144
# Epoch 43/100
# Learning rate:  0.0008
#  - 55s - loss: 2.5985 - val_loss: 3.4640
# Epoch 44/100
# Learning rate:  0.0008
#  - 55s - loss: 2.6181 - val_loss: 3.3402
# Epoch 45/100
# Learning rate:  0.0008
#  - 55s - loss: 2.6385 - val_loss: 3.3953
# Epoch 46/100
# Learning rate:  0.0008
#  - 55s - loss: 2.2864 - val_loss: 3.4305
# Epoch 47/100
# Learning rate:  0.0008
#  - 55s - loss: 2.4426 - val_loss: 3.3200
# Epoch 48/100
# Learning rate:  0.0008
#  - 55s - loss: 2.4796 - val_loss: 3.3246
# Epoch 49/100
# Learning rate:  0.0008
#  - 55s - loss: 2.5218 - val_loss: 3.1939
# Epoch 50/100
# Learning rate:  0.0008
#  - 55s - loss: 2.5845 - val_loss: 3.2744
# Epoch 51/100
# Learning rate:  0.0008
#  - 55s - loss: 2.2207 - val_loss: 3.3815
# Epoch 52/100
# Learning rate:  0.0008
#  - 57s - loss: 2.4110 - val_loss: 3.2661
# Epoch 53/100
# Learning rate:  0.0008
#  - 55s - loss: 2.5017 - val_loss: 3.1918
# Epoch 54/100
# Learning rate:  0.0008
#  - 55s - loss: 2.4474 - val_loss: 3.3532
# Epoch 55/100
# Learning rate:  0.0008
#  - 55s - loss: 2.1460 - val_loss: 3.3051
# Epoch 56/100
# Learning rate:  0.0008
#  - 55s - loss: 2.4519 - val_loss: 3.2616
# Epoch 57/100
# Learning rate:  0.0008
#  - 55s - loss: 2.3118 - val_loss: 3.3264
# Epoch 58/100
# Learning rate:  0.0008
#  - 55s - loss: 2.4749 - val_loss: 3.2850
# Epoch 59/100
# Learning rate:  0.0008
#  - 55s - loss: 2.3695 - val_loss: 3.1633
# Epoch 60/100
# Learning rate:  0.0008
#  - 55s - loss: 2.3749 - val_loss: 3.2092
# Epoch 61/100
# Learning rate:  0.0008
#  - 55s - loss: 2.3343 - val_loss: 3.2001
# Epoch 62/100
# Learning rate:  0.0007
#  - 55s - loss: 2.1637 - val_loss: 3.0733
# Epoch 63/100
# Learning rate:  0.0007
#  - 55s - loss: 2.2071 - val_loss: 3.1984
# Epoch 64/100
# Learning rate:  0.0007
#  - 55s - loss: 2.2140 - val_loss: 3.2332
# Epoch 65/100
# Learning rate:  0.0007
#  - 55s - loss: 2.3063 - val_loss: 3.2340
# Epoch 66/100
# Learning rate:  0.0007
#  - 55s - loss: 2.0416 - val_loss: 3.2178
# Epoch 67/100
# Learning rate:  0.0007
#  - 56s - loss: 2.1760 - val_loss: 3.3128
# Epoch 68/100
# Learning rate:  0.0007
#  - 55s - loss: 2.0902 - val_loss: 3.1147
# Epoch 69/100
# Learning rate:  0.0007
#  - 55s - loss: 2.1458 - val_loss: 3.1456
# Epoch 70/100
# Learning rate:  0.0007
#  - 55s - loss: 2.1736 - val_loss: 3.1230
# Epoch 71/100
# Learning rate:  0.0007
#  - 55s - loss: 2.0896 - val_loss: 3.1915
# Epoch 72/100
# Learning rate:  0.0007
#  - 55s - loss: 2.0606 - val_loss: 3.1061
# Epoch 73/100
# Learning rate:  0.0007
#  - 55s - loss: 1.9767 - val_loss: 3.0757
# Epoch 74/100
# Learning rate:  0.0007
#  - 56s - loss: 2.0831 - val_loss: 3.3867
# Epoch 75/100
# Learning rate:  0.0007
#  - 55s - loss: 2.0642 - val_loss: 3.3125
# Epoch 76/100
# Learning rate:  0.0007
#  - 55s - loss: 2.0809 - val_loss: 3.2768
# Epoch 77/100
# Learning rate:  0.0007
#  - 55s - loss: 2.0512 - val_loss: 3.2508
# Epoch 78/100
# Learning rate:  0.0007
#  - 56s - loss: 1.9578 - val_loss: 3.3106
# Epoch 79/100
# Learning rate:  0.0007
#  - 55s - loss: 2.1339 - val_loss: 3.2885
# Epoch 80/100
# Learning rate:  0.0007
#  - 55s - loss: 2.0219 - val_loss: 3.1833
# Epoch 81/100
# Learning rate:  0.0007
#  - 55s - loss: 2.0552 - val_loss: 3.2507
# Epoch 82/100
# Learning rate:  0.0006
#  - 55s - loss: 1.9870 - val_loss: 3.3366
# Epoch 83/100
# Learning rate:  0.0006
#  - 55s - loss: 1.9946 - val_loss: 3.2960
# Epoch 84/100
# Learning rate:  0.0006
#  - 56s - loss: 1.9994 - val_loss: 3.2447
# Epoch 85/100
# Learning rate:  0.0006
#  - 55s - loss: 1.8217 - val_loss: 3.2572
# Epoch 86/100
# Learning rate:  0.0006
#  - 55s - loss: 1.9733 - val_loss: 3.2285
# Epoch 87/100
# Learning rate:  0.0006
#  - 55s - loss: 1.8858 - val_loss: 3.3057
# Epoch 88/100
# Learning rate:  0.0006
#  - 55s - loss: 1.8034 - val_loss: 3.3724
# Epoch 89/100
# Learning rate:  0.0006
#  - 55s - loss: 1.9075 - val_loss: 3.2196
# Epoch 90/100
# Learning rate:  0.0006
#  - 55s - loss: 1.8243 - val_loss: 3.2265
# Epoch 91/100
# Learning rate:  0.0006
#  - 56s - loss: 1.8734 - val_loss: 3.2524
# Epoch 92/100
# Learning rate:  0.0006
#  - 55s - loss: 1.7843 - val_loss: 3.2161
# Epoch 93/100
# Learning rate:  0.0006
#  - 55s - loss: 1.8471 - val_loss: 3.1752
# Epoch 94/100
# Learning rate:  0.0006
#  - 55s - loss: 1.8677 - val_loss: 3.2715
# Epoch 95/100
# Learning rate:  0.0006
#  - 55s - loss: 1.8282 - val_loss: 3.1348
# Epoch 96/100
# Learning rate:  0.0006
#  - 55s - loss: 1.8454 - val_loss: 3.3202
# Epoch 97/100
# Learning rate:  0.0006
#  - 55s - loss: 1.7444 - val_loss: 3.2268
# Epoch 98/100
# Learning rate:  0.0006
#  - 55s - loss: 1.8585 - val_loss: 3.2456
# Epoch 99/100
# Learning rate:  0.0006
#  - 55s - loss: 1.8635 - val_loss: 3.1105
# Epoch 100/100
# Learning rate:  0.0006
#  - 55s - loss: 1.8367 - val_loss: 3.1378

# %%
# Visualize the training process
train_loss = history.history['loss']
val_loss = history.history['val_loss']

fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(train_loss, label='Training Loss')
ax.plot(val_loss, label='Validation Loss')
ax.set_title('Loss vs. Epochs', fontsize=16)
ax.set_xlabel('Epochs', fontsize=14)
ax.set_ylabel('Loss', fontsize=14)
ax.legend(fontsize=14)
ax.grid(True)
plt.show()

# %% [markdown]
# # Extract Features using Triplet Network

# %%
train_df = pd.read_csv('./data/triplet/train.csv')
val_df = pd.read_csv('./data/triplet/validation.csv')
test_df = pd.read_csv('./data/triplet/test.csv')

print('Train:\t\t', train_df.shape)
print('Validation:\t', val_df.shape)
print('Test:\t\t', test_df.shape)

print('\nTrain Landmarks:\t', len(train_df['landmark_id'].unique()))
print('Validation Landmarks:\t', len(val_df['landmark_id'].unique()))
print('Test Landmarks:\t\t', len(test_df['landmark_id'].unique()))
# Out:
# Train:		 (113783, 4)
# Validation:	 (22255, 4)
# Test:		 (22391, 4)
#
# Train Landmarks:	 14943
# Validation Landmarks:	 7674
# Test Landmarks:		 14436

# %%
# Load trained model
base_model = load_model('./models/vgg16-base(3)-model.h5')
base_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# max_pooling (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4608)              0
# _________________________________________________________________
# fc (Dense)                   (None, 512)               2359808
# _________________________________________________________________
# l2_norm (Lambda)             (None, 512)               0
# =================================================================
# Total params: 17,074,496
# Trainable params: 17,074,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define train_imgs and test_imgs
train_imgs = np.zeros(shape=(len(train_df), 512), dtype=np.float32)
val_imgs = np.zeros(shape=(len(val_df), 512), dtype=np.float32)
test_imgs = np.zeros(shape=(len(test_df), 512), dtype=np.float32)

# %%
# Process training images
img_ids = train_df['image_id'].values
steps = 20000
for i in range(0, len(train_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(train_df), i + steps)
    for idx in range(start, end):
        if idx % 250 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/train/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    train_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:      20000
# ================================================================================
# Process:      40000
# ================================================================================
# Process:      60000
# ================================================================================
# Process:      80000
# ================================================================================
# Process:     100000
# ========================================================

# %%
# Process validation images
img_ids = val_df['image_id'].values
steps = 4000
for i in range(0, len(val_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(val_df), i + steps)
    for idx in range(start, end):
        if idx % 50 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/validation/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    val_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:       4000
# ================================================================================
# Process:       8000
# ================================================================================
# Process:      12000
# ================================================================================
# Process:      16000
# ================================================================================
# Process:      20000
# ==============================================

# %%
# Process test images
img_ids = test_df['image_id'].values
steps = 4000
for i in range(0, len(test_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(test_df), i + steps)
    for idx in range(start, end):
        if idx % 50 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/test/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    test_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:       4000
# ================================================================================
# Process:       8000
# ================================================================================
# Process:      12000
# ================================================================================
# Process:      16000
# ================================================================================
# Process:      20000
# ================================================

# %%
print('Train:\t\t', train_imgs.shape)
print('Validation:\t', val_imgs.shape)
print('Test:\t\t', test_imgs.shape)
# Out:
# Train:		 (113783, 512)
# Validation:	 (22255, 512)
# Test:		 (22391, 512)

# %%
# Save to disk
np.save('./data/triplet/train_triplet_vgg16(3)_features.npy', train_imgs)
np.save('./data/triplet/validation_triplet_vgg16(3)_features.npy', val_imgs)
np.save('./data/triplet/test_triplet_vgg16(3)_features.npy', test_imgs)
