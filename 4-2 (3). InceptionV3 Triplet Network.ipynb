# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import random, gc, keras, os, pickle

from keras import backend as K
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential, load_model, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Input, Lambda
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.applications.inception_v3 import InceptionV3

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load Data

# %%
train_df = pd.read_csv('./data/triplet/train.csv')
val_df = pd.read_csv('./data/triplet/validation.csv')
test_df = pd.read_csv('./data/triplet/test.csv')

print('Train:\t\t', train_df.shape)
print('Validation:\t', val_df.shape)
print('Test:\t\t', test_df.shape)

print('\nTrain Landmarks:\t', len(train_df['landmark_id'].unique()))
print('Validation Landmarks:\t', len(val_df['landmark_id'].unique()))
print('Test Landmarks:\t\t', len(test_df['landmark_id'].unique()))
# Out:
# Train:		 (113783, 4)
# Validation:	 (22255, 4)
# Test:		 (22391, 4)
#
# Train Landmarks:	 14943
# Validation Landmarks:	 7674
# Test Landmarks:		 14436

# %%
train_df.head()
# Out:
#    image_id                id  \
# 0    465272  a2ccf8ed2e969f6a
# 1     64516  e205ca7c8dd7c027
# 2    928409  4e8ab93c1620e8a3
# 3     88809  896bf928214d1ca4
# 4   1001133  375d2a153bdca926
#
#                                                  url  landmark_id
# 0  https://lh4.googleusercontent.com/-TPHkS5gzvm4...            0
# 1  https://lh3.googleusercontent.com/-V3RjsZtGpxE...            0
# 2  http://mw2.google.com/mw-panoramio/photos/medi...            0
# 3  http://lh5.ggpht.com/-Cy0l41uUaGA/R--yB8vy41I/...            0
# 4  http://lh6.ggpht.com/-UqzFpnqE9bU/S_0u1RovfdI/...            0

# %% [markdown]
# # Helper Functions

# %%
# training set triplet generator
def train_triplet_generator(df, batch_size=74, img_size=(224, 224), seed=42, 
                            prefix='./data/triplet/train/'):
    """ training set triplet generator
        it will generate 7400 triplet images in total
    """
    # get images with only one training image landmark id and the rest landmark ids
    np.random.seed(seed)
    grouped = df[['landmark_id', 'image_id']].groupby('landmark_id').count().reset_index()
    unique_neg_ids = list(grouped[grouped['image_id'] == 1]['landmark_id'].values)
    rest_ids = list(grouped[grouped['image_id'] > 1]['landmark_id'].values)
    size = 7400 * 2 - len(unique_neg_ids) 
    zeros = np.zeros((batch_size, 3, 1), dtype=K.floatx())
    
    while True:
        # get positive and negative image landmark ids
        np.random.shuffle(rest_ids)
        candidate_ids = list(np.random.choice(rest_ids, size=size, replace=False))
        pos_landmark_ids = candidate_ids[:7400]
        neg_landmark_ids = candidate_ids[7400:] + unique_neg_ids
        np.random.shuffle(neg_landmark_ids)
        
        # transform landmark id into image id
        anc_img_ids = []
        pos_img_ids = []
        neg_img_ids = []
        
        for i in range(len(pos_landmark_ids)):
            tmp_pos_ids = df[df['landmark_id'] == pos_landmark_ids[i]]['image_id'].values
            anc_img_ids.append(tmp_pos_ids[0])
            pos_img_ids.append(tmp_pos_ids[1])
            
            tmp_neg_ids = df[df['landmark_id'] == neg_landmark_ids[i]]['image_id'].values
            neg_img_ids.append(tmp_neg_ids[0])
        
        # iterator to read batch images
        for j in range(len(pos_img_ids) // batch_size):
            batch_anc_img_ids = anc_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_pos_img_ids = pos_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_neg_img_ids = neg_img_ids[j * batch_size: (j + 1) * batch_size]
            
            # get images
            anc_imgs = []
            pos_imgs = []
            neg_imgs = []
            
            # iteratively read images
            for k in range(batch_size):
                anc_path = prefix + str(batch_anc_img_ids[k]) + '.jpg'
                pos_path = prefix + str(batch_pos_img_ids[k]) + '.jpg'
                neg_path = prefix + str(batch_neg_img_ids[k]) + '.jpg'
                
                tmp_anc_img = load_img(anc_path, target_size=img_size)
                tmp_anc_img = img_to_array(tmp_anc_img)
                anc_imgs.append(tmp_anc_img)
                
                tmp_pos_img = load_img(pos_path, target_size=img_size)
                tmp_pos_img = img_to_array(tmp_pos_img)
                pos_imgs.append(tmp_pos_img)
                
                tmp_neg_img = load_img(neg_path, target_size=img_size)
                tmp_neg_img = img_to_array(tmp_neg_img)
                neg_imgs.append(tmp_neg_img)
        
            # transform list to array
            anc_imgs = np.array(anc_imgs, dtype=K.floatx()) / 255.0
            pos_imgs = np.array(pos_imgs, dtype=K.floatx()) / 255.0
            neg_imgs = np.array(neg_imgs, dtype=K.floatx()) / 255.0

            yield [anc_imgs, pos_imgs, neg_imgs], zeros

# %%
# validation set triplet generator
def val_triplet_generator(df, batch_size=128, img_size=(224, 224), 
                          seed=42, prefix='./data/triplet/validation'):
    """ validation set triplet collector """
    
     # get images with only one image landmark id and the rest landmark ids
    grouped = df[['landmark_id', 'image_id']].groupby('landmark_id').count().reset_index()
    unique_neg_ids = list(grouped[grouped['image_id'] == 1]['landmark_id'].values)
    rest_ids = list(grouped[grouped['image_id'] > 1]['landmark_id'].values)
    size = 3072 * 2 - len(unique_neg_ids) 
    zeros = np.zeros((batch_size, 3, 1), dtype=K.floatx())
    
    while True:
        # get positive and negative image landmark ids
        np.random.seed(seed)
        candidate_ids = list(np.random.choice(rest_ids, size=size, replace=False))
        pos_landmark_ids = candidate_ids[:3072]
        neg_landmark_ids = candidate_ids[3072:] + unique_neg_ids
        np.random.shuffle(neg_landmark_ids)
        
        # transform landmark id into image id
        anc_img_ids = []
        pos_img_ids = []
        neg_img_ids = []
        
        for i in range(len(pos_landmark_ids)):
            tmp_pos_ids = df[df['landmark_id'] == pos_landmark_ids[i]]['image_id'].values
            anc_img_ids.append(tmp_pos_ids[0])
            pos_img_ids.append(tmp_pos_ids[1])
            
            tmp_neg_ids = df[df['landmark_id'] == neg_landmark_ids[i]]['image_id'].values
            neg_img_ids.append(tmp_neg_ids[0])
        
        # iterator to read batch images
        for j in range(len(pos_img_ids) // batch_size):
            batch_anc_img_ids = anc_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_pos_img_ids = pos_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_neg_img_ids = neg_img_ids[j * batch_size: (j + 1) * batch_size]
            
            # get images
            anc_imgs = []
            pos_imgs = []
            neg_imgs = []
            
            # iteratively read images
            for k in range(batch_size):
                anc_path = prefix + str(batch_anc_img_ids[k]) + '.jpg'
                pos_path = prefix + str(batch_pos_img_ids[k]) + '.jpg'
                neg_path = prefix + str(batch_neg_img_ids[k]) + '.jpg'
                
                tmp_anc_img = load_img(anc_path, target_size=img_size)
                tmp_anc_img = img_to_array(tmp_anc_img)
                anc_imgs.append(tmp_anc_img)
                
                tmp_pos_img = load_img(pos_path, target_size=img_size)
                tmp_pos_img = img_to_array(tmp_pos_img)
                pos_imgs.append(tmp_pos_img)
                
                tmp_neg_img = load_img(neg_path, target_size=img_size)
                tmp_neg_img = img_to_array(tmp_neg_img)
                neg_imgs.append(tmp_neg_img)
        
            # transform list to array
            anc_imgs = np.array(anc_imgs, dtype=K.floatx()) / 255.0
            pos_imgs = np.array(pos_imgs, dtype=K.floatx()) / 255.0
            neg_imgs = np.array(neg_imgs, dtype=K.floatx()) / 255.0
            
            yield [anc_imgs, pos_imgs, neg_imgs], zeros

# %% [markdown]
# # Define Triplet Loss Model

# %%
# Define base network for triplet network
def base_net(input_shape=(224, 224, 3), trainable=False):
    """ define triplet network """
    # load pre-trained InceptionV3 model
    inception = InceptionV3(include_top=False, weights='imagenet', input_shape=input_shape)
    inception.trainable = trainable
    
    # define sequential model
    model = Sequential(name='base_net')
    model.add(inception)
    model.add(Flatten(name='flatten'))
    model.add(Dropout(rate=0.5, name='dropout'))
    model.add(Dense(1024, activation=None, name='fc'))
    model.add(Lambda(lambda x: K.l2_normalize(x, axis=1), name='l2_norm'))
    
    return model

# %%
# Define triplet network
def triplet_net(base_model, input_shape=(224, 224, 3)):
    """ function to define triplet networks """
    # define input: anchor, positive, negative
    anchor = Input(shape=input_shape, name='anchor_input')
    positive = Input(shape=input_shape, name='positive_input')
    negative = Input(shape=input_shape, name='negative_input')
    
    # extract vector represent using CNN based model
    anc_vec = base_model(anchor)
    pos_vec = base_model(positive)
    neg_vec = base_model(negative)
    
    # stack outputs
    stacks = Lambda(lambda x: K.stack(x, axis=1), name='output')([anc_vec, pos_vec, neg_vec])

    # define inputs and outputs
    inputs=[anchor, positive, negative]
    outputs = stacks
    
    # define the triplet model
    model = Model(inputs=inputs, outputs=outputs, name='triplet_net')
    
    return model

# %%
# Define triplet loss
def triplet_loss(y_true, y_pred):
    """ function to compute triplet loss
        margin is predefined coded, manually change if needed
    """
    # define triplet margin
    margin = K.constant(0.3)
    zero = K.constant(0.0)
    
    # get the prediction vector
    anchor, positive, negative = y_pred[:, 0], y_pred[:, 1], y_pred[:, 2]
    
    # compute distance
    pos_distance = K.sum(K.square(anchor - positive), axis=1)
    neg_distance = K.sum(K.square(anchor - negative), axis=1)
    
    # compute loss
    partial_loss = pos_distance - neg_distance + margin
    full_loss = K.sum(K.maximum(partial_loss, zero), axis=0)
    
    return full_loss

# %% [markdown]
# # Build Triplet Model

# %%
# For reproduciable purpose
seed = 42
K.clear_session()
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(seed)
random.seed(seed)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.set_random_seed(seed)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# Define Parameters
img_size = (224, 224, 3)  # target image size

# triplet image generator
train_generator = train_triplet_generator(train_df, batch_size=74, img_size=img_size[:2], 
                                          seed=42, prefix='./data/triplet/train/')

val_generator = val_triplet_generator(val_df, batch_size=64, img_size=img_size[:2], 
                                      seed=42, prefix='./data/triplet/validation/')

# %%
# Define triplet network model
base_model = base_net(input_shape=img_size, trainable=False)
base_model.summary()
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3148: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Model)         (None, 5, 5, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 51200)             0
# _________________________________________________________________
# fc (Dense)                   (None, 1024)              52429824
# _________________________________________________________________
# l2_norm (Lambda)             (None, 1024)              0
# =================================================================
# Total params: 74,232,608
# Trainable params: 52,429,824
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
triplet_model = triplet_net(base_model=base_model, input_shape=img_size)
triplet_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# anchor_input (InputLayer)       (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# positive_input (InputLayer)     (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# negative_input (InputLayer)     (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# base_net (Sequential)           (None, 1024)         74232608    anchor_input[0][0]
#                                                                  positive_input[0][0]
#                                                                  negative_input[0][0]
# __________________________________________________________________________________________________
# output (Lambda)                 (None, 3, 1024)      0           base_net[1][0]
#                                                                  base_net[2][0]
#                                                                  base_net[3][0]
# ==================================================================================================
# Total params: 74,232,608
# Trainable params: 52,429,824
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %% [markdown]
# # Fit Triplet Model

# %%
# define learning scheduler
def lr_schedule(epoch):
    """ Learning rate schedule """
    lr = 1e-3
    if epoch > 80:
        lr *= 6e-1
    elif epoch > 60:
        lr *= 7e-1
    elif epoch > 40:
        lr *= 8e-1
    elif epoch > 20:
        lr *= 9e-1
    print('Learning rate: ', lr)
    return lr

# define optimizer
opt = keras.optimizers.Adam(lr=lr_schedule(0))

# Create call backs
checkpoint = ModelCheckpoint(filepath='./models/inception-triplet(3)-ckpt.h5', 
                             monitor='val_loss', save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# compile the model
triplet_model.compile(optimizer=opt, loss=triplet_loss)
# Out:
# Learning rate:  0.001

# %%
# fit the mode
history = triplet_model.fit_generator(train_generator, steps_per_epoch=100, epochs=100, 
                                      validation_data=val_generator, validation_steps=48, 
                                      verbose=2, callbacks=callbacks)

triplet_model.save('./models/inception-triplet(3)-model.h5')
base_model.save('./models/inception-base(3)-model.h5')
pickle.dump(history.history, open('./models/inception-triplet(3)-history.p', 'wb'))
_ = gc.collect()
# Out:
# Epoch 1/100
# Learning rate:  0.001
#  - 74s - loss: 8.9275 - val_loss: 5.3842
# Epoch 2/100
# Learning rate:  0.001
#  - 52s - loss: 5.2127 - val_loss: 4.8723
# Epoch 3/100
# Learning rate:  0.001
#  - 52s - loss: 4.3352 - val_loss: 4.3606
# Epoch 4/100
# Learning rate:  0.001
#  - 53s - loss: 3.9330 - val_loss: 4.3659
# Epoch 5/100
# Learning rate:  0.001
#  - 52s - loss: 3.4631 - val_loss: 4.2947
# Epoch 6/100
# Learning rate:  0.001
#  - 52s - loss: 3.0872 - val_loss: 4.4233
# Epoch 7/100
# Learning rate:  0.001
#  - 52s - loss: 2.5539 - val_loss: 4.2790
# Epoch 8/100
# Learning rate:  0.001
#  - 52s - loss: 2.6034 - val_loss: 4.0228
# Epoch 9/100
# Learning rate:  0.001
#  - 53s - loss: 2.5530 - val_loss: 3.9863
# Epoch 10/100
# Learning rate:  0.001
#  - 53s - loss: 2.1850 - val_loss: 4.0500
# Epoch 11/100
# Learning rate:  0.001
#  - 53s - loss: 2.0151 - val_loss: 4.1064
# Epoch 12/100
# Learning rate:  0.001
#  - 53s - loss: 1.9336 - val_loss: 3.9346
# Epoch 13/100
# Learning rate:  0.001
#  - 54s - loss: 1.8456 - val_loss: 3.9163
# Epoch 14/100
# Learning rate:  0.001
#  - 53s - loss: 1.7741 - val_loss: 3.7872
# Epoch 15/100
# Learning rate:  0.001
#  - 53s - loss: 1.5641 - val_loss: 3.7783
# Epoch 16/100
# Learning rate:  0.001
#  - 55s - loss: 1.6640 - val_loss: 3.7396
# Epoch 17/100
# Learning rate:  0.001
#  - 53s - loss: 1.5446 - val_loss: 3.9591
# Epoch 18/100
# Learning rate:  0.001
#  - 53s - loss: 1.6479 - val_loss: 3.9369
# Epoch 19/100
# Learning rate:  0.001
#  - 54s - loss: 1.4366 - val_loss: 3.9062
# Epoch 20/100
# Learning rate:  0.001
#  - 53s - loss: 1.3104 - val_loss: 3.8769
# Epoch 21/100
# Learning rate:  0.001
#  - 53s - loss: 1.2960 - val_loss: 3.9070
# Epoch 22/100
# Learning rate:  0.0009000000000000001
#  - 52s - loss: 1.2903 - val_loss: 3.8172
# Epoch 23/100
# Learning rate:  0.0009000000000000001
#  - 53s - loss: 1.3148 - val_loss: 3.7772
# Epoch 24/100
# Learning rate:  0.0009000000000000001
#  - 53s - loss: 1.3337 - val_loss: 3.7467
# Epoch 25/100
# Learning rate:  0.0009000000000000001
#  - 54s - loss: 1.1937 - val_loss: 3.7316
# Epoch 26/100
# Learning rate:  0.0009000000000000001
#  - 53s - loss: 1.0138 - val_loss: 3.7704
# Epoch 27/100
# Learning rate:  0.0009000000000000001
#  - 53s - loss: 1.0066 - val_loss: 3.6828
# Epoch 28/100
# Learning rate:  0.0009000000000000001
#  - 53s - loss: 1.0710 - val_loss: 3.7184
# Epoch 29/100
# Learning rate:  0.0009000000000000001
#  - 53s - loss: 0.9990 - val_loss: 3.6976
# Epoch 30/100
# Learning rate:  0.0009000000000000001
#  - 52s - loss: 1.0337 - val_loss: 3.7646
# Epoch 31/100
# Learning rate:  0.0009000000000000001
#  - 53s - loss: 1.0081 - val_loss: 3.8638
# Epoch 32/100
# Learning rate:  0.0009000000000000001
#  - 53s - loss: 0.9558 - val_loss: 3.7474
# Epoch 33/100
# Learning rate:  0.0009000000000000001
#  - 53s - loss: 1.0455 - val_loss: 3.6627
# Epoch 34/100
# Learning rate:  0.0009000000000000001
#  - 52s - loss: 1.0005 - val_loss: 3.7405
# Epoch 35/100
# Learning rate:  0.0009000000000000001
#  - 54s - loss: 0.9341 - val_loss: 3.7161
# Epoch 36/100
# Learning rate:  0.0009000000000000001
#  - 55s - loss: 0.8159 - val_loss: 3.6898
# Epoch 37/100
# Learning rate:  0.0009000000000000001
#  - 52s - loss: 1.0179 - val_loss: 3.7503
# Epoch 38/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 0.8746 - val_loss: 3.6332
# Epoch 39/100
# Learning rate:  0.0009000000000000001
#  - 52s - loss: 0.8902 - val_loss: 3.6618
# Epoch 40/100
# Learning rate:  0.0009000000000000001
#  - 52s - loss: 0.8672 - val_loss: 3.7949
# Epoch 41/100
# Learning rate:  0.0009000000000000001
#  - 52s - loss: 0.8816 - val_loss: 3.8098
# Epoch 42/100
# Learning rate:  0.0008
#  - 52s - loss: 0.7896 - val_loss: 3.7305
# Epoch 43/100
# Learning rate:  0.0008
#  - 52s - loss: 0.8507 - val_loss: 3.7064
# Epoch 44/100
# Learning rate:  0.0008
#  - 52s - loss: 0.8243 - val_loss: 3.6614
# Epoch 45/100
# Learning rate:  0.0008
#  - 52s - loss: 0.8111 - val_loss: 3.7119
# Epoch 46/100
# Learning rate:  0.0008
#  - 52s - loss: 0.7624 - val_loss: 3.6986
# Epoch 47/100
# Learning rate:  0.0008
#  - 54s - loss: 0.7288 - val_loss: 3.8042
# Epoch 48/100
# Learning rate:  0.0008
#  - 53s - loss: 0.6772 - val_loss: 3.6684
# Epoch 49/100
# Learning rate:  0.0008
#  - 52s - loss: 0.6753 - val_loss: 3.7184
# Epoch 50/100
# Learning rate:  0.0008
#  - 53s - loss: 0.6514 - val_loss: 3.7384
# Epoch 51/100
# Learning rate:  0.0008
#  - 53s - loss: 0.6516 - val_loss: 3.7953
# Epoch 52/100
# Learning rate:  0.0008
#  - 53s - loss: 0.7226 - val_loss: 3.7174
# Epoch 53/100
# Learning rate:  0.0008
#  - 58s - loss: 0.6609 - val_loss: 3.6731
# Epoch 54/100
# Learning rate:  0.0008
#  - 53s - loss: 0.7389 - val_loss: 3.6446
# Epoch 55/100
# Learning rate:  0.0008
#  - 53s - loss: 0.6770 - val_loss: 3.8034
# Epoch 56/100
# Learning rate:  0.0008
#  - 52s - loss: 0.6597 - val_loss: 3.6160
# Epoch 57/100
# Learning rate:  0.0008
#  - 52s - loss: 0.7154 - val_loss: 3.5651
# Epoch 58/100
# Learning rate:  0.0008
#  - 51s - loss: 0.6335 - val_loss: 3.6509
# Epoch 59/100
# Learning rate:  0.0008
#  - 53s - loss: 0.6632 - val_loss: 3.6901
# Epoch 60/100
# Learning rate:  0.0008
#  - 53s - loss: 0.5401 - val_loss: 3.6441
# Epoch 61/100
# Learning rate:  0.0008
#  - 52s - loss: 0.6831 - val_loss: 3.7531
# Epoch 62/100
# Learning rate:  0.0007
#  - 53s - loss: 0.6600 - val_loss: 3.6702
# Epoch 63/100
# Learning rate:  0.0007
#  - 52s - loss: 0.5706 - val_loss: 3.6727
# Epoch 64/100
# Learning rate:  0.0007
#  - 53s - loss: 0.5213 - val_loss: 3.7315
# Epoch 65/100
# Learning rate:  0.0007
#  - 53s - loss: 0.5844 - val_loss: 3.7371
# Epoch 66/100
# Learning rate:  0.0007
#  - 52s - loss: 0.5841 - val_loss: 3.7076
# Epoch 67/100
# Learning rate:  0.0007
#  - 52s - loss: 0.6428 - val_loss: 3.7444
# Epoch 68/100
# Learning rate:  0.0007
#  - 54s - loss: 0.5685 - val_loss: 3.6383
# Epoch 69/100
# Learning rate:  0.0007
#  - 52s - loss: 0.5523 - val_loss: 3.8804
# Epoch 70/100
# Learning rate:  0.0007
#  - 52s - loss: 0.5172 - val_loss: 3.7509
# Epoch 71/100
# Learning rate:  0.0007
#  - 53s - loss: 0.5128 - val_loss: 3.6302
# Epoch 72/100
# Learning rate:  0.0007
#  - 52s - loss: 0.4895 - val_loss: 3.7560
# Epoch 73/100
# Learning rate:  0.0007
#  - 53s - loss: 0.4780 - val_loss: 3.6264
# Epoch 74/100
# Learning rate:  0.0007
#  - 52s - loss: 0.5115 - val_loss: 3.6480
# Epoch 75/100
# Learning rate:  0.0007
#  - 55s - loss: 0.5186 - val_loss: 3.6300
# Epoch 76/100
# Learning rate:  0.0007
#  - 52s - loss: 0.4440 - val_loss: 3.7568
# Epoch 77/100
# Learning rate:  0.0007
#  - 52s - loss: 0.4251 - val_loss: 3.6046
# Epoch 78/100
# Learning rate:  0.0007
#  - 52s - loss: 0.5058 - val_loss: 3.6961
# Epoch 79/100
# Learning rate:  0.0007
#  - 53s - loss: 0.5466 - val_loss: 3.5752
# Epoch 80/100
# Learning rate:  0.0007
#  - 52s - loss: 0.4908 - val_loss: 3.6921
# Epoch 81/100
# Learning rate:  0.0007
#  - 53s - loss: 0.5012 - val_loss: 3.6390
# Epoch 82/100
# Learning rate:  0.0006
#  - 53s - loss: 0.4198 - val_loss: 3.5734
# Epoch 83/100
# Learning rate:  0.0006
#  - 53s - loss: 0.4282 - val_loss: 3.5770
# Epoch 84/100
# Learning rate:  0.0006
#  - 53s - loss: 0.4239 - val_loss: 3.6809
# Epoch 85/100
# Learning rate:  0.0006
#  - 52s - loss: 0.4294 - val_loss: 3.6517
# Epoch 86/100
# Learning rate:  0.0006
#  - 52s - loss: 0.4473 - val_loss: 3.7099
# Epoch 87/100
# Learning rate:  0.0006
#  - 52s - loss: 0.4404 - val_loss: 3.7593
# Epoch 88/100
# Learning rate:  0.0006
#  - 52s - loss: 0.4179 - val_loss: 3.6436
# Epoch 89/100
# Learning rate:  0.0006
#  - 53s - loss: 0.4110 - val_loss: 3.6189
# Epoch 90/100
# Learning rate:  0.0006
#  - 53s - loss: 0.4329 - val_loss: 3.6891
# Epoch 91/100
# Learning rate:  0.0006
#  - 52s - loss: 0.3916 - val_loss: 3.6263
# Epoch 92/100
# Learning rate:  0.0006
#  - 52s - loss: 0.3658 - val_loss: 3.8247
# Epoch 93/100
# Learning rate:  0.0006
#  - 52s - loss: 0.4195 - val_loss: 3.8008
# Epoch 94/100
# Learning rate:  0.0006
#  - 52s - loss: 0.3759 - val_loss: 3.7342
# Epoch 95/100
# Learning rate:  0.0006
#  - 52s - loss: 0.3854 - val_loss: 3.7378
# Epoch 96/100
# Learning rate:  0.0006
#  - 53s - loss: 0.4007 - val_loss: 3.6482
# Epoch 97/100
# Learning rate:  0.0006
#  - 54s - loss: 0.3482 - val_loss: 3.6346
# Epoch 98/100
# Learning rate:  0.0006
#  - 54s - loss: 0.3588 - val_loss: 3.7621
# Epoch 99/100
# Learning rate:  0.0006
#  - 52s - loss: 0.4002 - val_loss: 3.6979
# Epoch 100/100
# Learning rate:  0.0006
#  - 53s - loss: 0.4026 - val_loss: 3.6954

# %%
# Visualize the training process
train_loss = history.history['loss']
val_loss = history.history['val_loss']

fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(train_loss, label='Training Loss')
ax.plot(val_loss, label='Validation Loss')
ax.set_title('Loss vs. Epochs', fontsize=16)
ax.set_xlabel('Epochs', fontsize=14)
ax.set_ylabel('Loss', fontsize=14)
ax.legend(fontsize=14)
ax.grid(True)
plt.show()

# %% [markdown]
# # Extract Features using Triplet Network

# %%
train_df = pd.read_csv('./data/triplet/train.csv')
val_df = pd.read_csv('./data/triplet/validation.csv')
test_df = pd.read_csv('./data/triplet/test.csv')

print('Train:\t\t', train_df.shape)
print('Validation:\t', val_df.shape)
print('Test:\t\t', test_df.shape)

print('\nTrain Landmarks:\t', len(train_df['landmark_id'].unique()))
print('Validation Landmarks:\t', len(val_df['landmark_id'].unique()))
print('Test Landmarks:\t\t', len(test_df['landmark_id'].unique()))
# Out:
# Train:		 (113783, 4)
# Validation:	 (22255, 4)
# Test:		 (22391, 4)
#
# Train Landmarks:	 14943
# Validation Landmarks:	 7674
# Test Landmarks:		 14436

# %%
# Load trained model
base_model = load_model('./models/inception-base(3)-model.h5')
base_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Model)         (None, 5, 5, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 51200)             0
# _________________________________________________________________
# fc (Dense)                   (None, 1024)              52429824
# _________________________________________________________________
# l2_norm (Lambda)             (None, 1024)              0
# =================================================================
# Total params: 74,232,608
# Trainable params: 74,198,176
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
# Define train_imgs and test_imgs
train_imgs = np.zeros(shape=(len(train_df), 1024), dtype=np.float32)
val_imgs = np.zeros(shape=(len(val_df), 1024), dtype=np.float32)
test_imgs = np.zeros(shape=(len(test_df), 1024), dtype=np.float32)

# %%
# Process training images
img_ids = train_df['image_id'].values
steps = 20000
for i in range(0, len(train_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(train_df), i + steps)
    for idx in range(start, end):
        if idx % 250 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/train/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    train_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:      20000
# ================================================================================
# Process:      40000
# ================================================================================
# Process:      60000
# ================================================================================
# Process:      80000
# ================================================================================
# Process:     100000
# ========================================================

# %%
# Process validation images
img_ids = val_df['image_id'].values
steps = 4000
for i in range(0, len(val_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(val_df), i + steps)
    for idx in range(start, end):
        if idx % 50 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/validation/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    val_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:       4000
# ================================================================================
# Process:       8000
# ================================================================================
# Process:      12000
# ================================================================================
# Process:      16000
# ================================================================================
# Process:      20000
# ==============================================

# %%
# Process test images
img_ids = test_df['image_id'].values
steps = 4000
for i in range(0, len(test_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(test_df), i + steps)
    for idx in range(start, end):
        if idx % 50 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/test/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    test_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:       4000
# ================================================================================
# Process:       8000
# ================================================================================
# Process:      12000
# ================================================================================
# Process:      16000
# ================================================================================
# Process:      20000
# ================================================

# %%
print('Train:\t\t', train_imgs.shape)
print('Validation:\t', val_imgs.shape)
print('Test:\t\t', test_imgs.shape)
# Out:
# Train:		 (113783, 1024)
# Validation:	 (22255, 1024)
# Test:		 (22391, 1024)

# %%
# Save to disk
np.save('./data/triplet/train_triplet_inception(3)_features.npy', train_imgs)
np.save('./data/triplet/validation_triplet_inception(3)_features.npy', val_imgs)
np.save('./data/triplet/test_triplet_inception(3)_features.npy', test_imgs)
