# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import random, gc, keras, os, pickle

from keras import backend as K
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential, load_model, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Input, Lambda
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load Data

# %%
train_df = pd.read_csv('./data/triplet/train.csv')
val_df = pd.read_csv('./data/triplet/validation.csv')
test_df = pd.read_csv('./data/triplet/test.csv')

print('Train:\t\t', train_df.shape)
print('Validation:\t', val_df.shape)
print('Test:\t\t', test_df.shape)

print('\nTrain Landmarks:\t', len(train_df['landmark_id'].unique()))
print('Validation Landmarks:\t', len(val_df['landmark_id'].unique()))
print('Test Landmarks:\t\t', len(test_df['landmark_id'].unique()))
# Out:
# Train:		 (113783, 4)
# Validation:	 (22255, 4)
# Test:		 (22391, 4)
#
# Train Landmarks:	 14943
# Validation Landmarks:	 7674
# Test Landmarks:		 14436

# %%
train_df.head()
# Out:
#    image_id                id  \
# 0    465272  a2ccf8ed2e969f6a
# 1     64516  e205ca7c8dd7c027
# 2    928409  4e8ab93c1620e8a3
# 3     88809  896bf928214d1ca4
# 4   1001133  375d2a153bdca926
#
#                                                  url  landmark_id
# 0  https://lh4.googleusercontent.com/-TPHkS5gzvm4...            0
# 1  https://lh3.googleusercontent.com/-V3RjsZtGpxE...            0
# 2  http://mw2.google.com/mw-panoramio/photos/medi...            0
# 3  http://lh5.ggpht.com/-Cy0l41uUaGA/R--yB8vy41I/...            0
# 4  http://lh6.ggpht.com/-UqzFpnqE9bU/S_0u1RovfdI/...            0

# %% [markdown]
# # Helper Functions

# %%
# training set triplet generator
def train_triplet_generator(df, batch_size=74, img_size=(224, 224), seed=42, 
                            prefix='./data/triplet/train/'):
    """ training set triplet generator
        it will generate 7400 triplet images in total
    """
    # get images with only one training image landmark id and the rest landmark ids
    np.random.seed(seed)
    grouped = df[['landmark_id', 'image_id']].groupby('landmark_id').count().reset_index()
    unique_neg_ids = list(grouped[grouped['image_id'] == 1]['landmark_id'].values)
    rest_ids = list(grouped[grouped['image_id'] > 1]['landmark_id'].values)
    size = 7400 * 2 - len(unique_neg_ids) 
    zeros = np.zeros((batch_size, 3, 1), dtype=K.floatx())
    
    while True:
        # get positive and negative image landmark ids
        np.random.shuffle(rest_ids)
        candidate_ids = list(np.random.choice(rest_ids, size=size, replace=False))
        pos_landmark_ids = candidate_ids[:7400]
        neg_landmark_ids = candidate_ids[7400:] + unique_neg_ids
        np.random.shuffle(neg_landmark_ids)
        
        # transform landmark id into image id
        anc_img_ids = []
        pos_img_ids = []
        neg_img_ids = []
        
        for i in range(len(pos_landmark_ids)):
            tmp_pos_ids = df[df['landmark_id'] == pos_landmark_ids[i]]['image_id'].values
            anc_img_ids.append(tmp_pos_ids[0])
            pos_img_ids.append(tmp_pos_ids[1])
            
            tmp_neg_ids = df[df['landmark_id'] == neg_landmark_ids[i]]['image_id'].values
            neg_img_ids.append(tmp_neg_ids[0])
        
        # iterator to read batch images
        for j in range(len(pos_img_ids) // batch_size):
            batch_anc_img_ids = anc_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_pos_img_ids = pos_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_neg_img_ids = neg_img_ids[j * batch_size: (j + 1) * batch_size]
            
            # get images
            anc_imgs = []
            pos_imgs = []
            neg_imgs = []
            
            # iteratively read images
            for k in range(batch_size):
                anc_path = prefix + str(batch_anc_img_ids[k]) + '.jpg'
                pos_path = prefix + str(batch_pos_img_ids[k]) + '.jpg'
                neg_path = prefix + str(batch_neg_img_ids[k]) + '.jpg'
                
                tmp_anc_img = load_img(anc_path, target_size=img_size)
                tmp_anc_img = img_to_array(tmp_anc_img)
                anc_imgs.append(tmp_anc_img)
                
                tmp_pos_img = load_img(pos_path, target_size=img_size)
                tmp_pos_img = img_to_array(tmp_pos_img)
                pos_imgs.append(tmp_pos_img)
                
                tmp_neg_img = load_img(neg_path, target_size=img_size)
                tmp_neg_img = img_to_array(tmp_neg_img)
                neg_imgs.append(tmp_neg_img)
        
            # transform list to array
            anc_imgs = np.array(anc_imgs, dtype=K.floatx()) / 255.0
            pos_imgs = np.array(pos_imgs, dtype=K.floatx()) / 255.0
            neg_imgs = np.array(neg_imgs, dtype=K.floatx()) / 255.0

            yield [anc_imgs, pos_imgs, neg_imgs], zeros

# %%
# validation set triplet generator
def val_triplet_generator(df, batch_size=128, img_size=(224, 224), 
                          seed=42, prefix='./data/triplet/validation'):
    """ validation set triplet collector """
    
     # get images with only one image landmark id and the rest landmark ids
    grouped = df[['landmark_id', 'image_id']].groupby('landmark_id').count().reset_index()
    unique_neg_ids = list(grouped[grouped['image_id'] == 1]['landmark_id'].values)
    rest_ids = list(grouped[grouped['image_id'] > 1]['landmark_id'].values)
    size = 3072 * 2 - len(unique_neg_ids) 
    zeros = np.zeros((batch_size, 3, 1), dtype=K.floatx())
    
    while True:
        # get positive and negative image landmark ids
        np.random.seed(seed)
        candidate_ids = list(np.random.choice(rest_ids, size=size, replace=False))
        pos_landmark_ids = candidate_ids[:3072]
        neg_landmark_ids = candidate_ids[3072:] + unique_neg_ids
        np.random.shuffle(neg_landmark_ids)
        
        # transform landmark id into image id
        anc_img_ids = []
        pos_img_ids = []
        neg_img_ids = []
        
        for i in range(len(pos_landmark_ids)):
            tmp_pos_ids = df[df['landmark_id'] == pos_landmark_ids[i]]['image_id'].values
            anc_img_ids.append(tmp_pos_ids[0])
            pos_img_ids.append(tmp_pos_ids[1])
            
            tmp_neg_ids = df[df['landmark_id'] == neg_landmark_ids[i]]['image_id'].values
            neg_img_ids.append(tmp_neg_ids[0])
        
        # iterator to read batch images
        for j in range(len(pos_img_ids) // batch_size):
            batch_anc_img_ids = anc_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_pos_img_ids = pos_img_ids[j * batch_size: (j + 1) * batch_size]
            batch_neg_img_ids = neg_img_ids[j * batch_size: (j + 1) * batch_size]
            
            # get images
            anc_imgs = []
            pos_imgs = []
            neg_imgs = []
            
            # iteratively read images
            for k in range(batch_size):
                anc_path = prefix + str(batch_anc_img_ids[k]) + '.jpg'
                pos_path = prefix + str(batch_pos_img_ids[k]) + '.jpg'
                neg_path = prefix + str(batch_neg_img_ids[k]) + '.jpg'
                
                tmp_anc_img = load_img(anc_path, target_size=img_size)
                tmp_anc_img = img_to_array(tmp_anc_img)
                anc_imgs.append(tmp_anc_img)
                
                tmp_pos_img = load_img(pos_path, target_size=img_size)
                tmp_pos_img = img_to_array(tmp_pos_img)
                pos_imgs.append(tmp_pos_img)
                
                tmp_neg_img = load_img(neg_path, target_size=img_size)
                tmp_neg_img = img_to_array(tmp_neg_img)
                neg_imgs.append(tmp_neg_img)
        
            # transform list to array
            anc_imgs = np.array(anc_imgs, dtype=K.floatx()) / 255.0
            pos_imgs = np.array(pos_imgs, dtype=K.floatx()) / 255.0
            neg_imgs = np.array(neg_imgs, dtype=K.floatx()) / 255.0
            
            yield [anc_imgs, pos_imgs, neg_imgs], zeros

# %% [markdown]
# # Define Triplet Loss Model

# %%
# Define base network for triplet network
def base_net(input_shape=(224, 224, 3), trainable=False):
    """ define triplet network """
    # load pre-trained VGG16 model
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=input_shape)
    vgg16.trainable = trainable
    
    # define sequential model
    model = Sequential(name='base_net')
    model.add(vgg16)
    model.add(Flatten(name='flatten'))
    model.add(Dropout(rate=0.5, name='dropout'))
    model.add(Dense(512, activation=None, name='fc'))
    model.add(Lambda(lambda x: K.l2_normalize(x, axis=1), name='l2_norm'))
    
    return model

# %%
# Define triplet network
def triplet_net(base_model, input_shape=(224, 224, 3)):
    """ function to define triplet networks """
    # define input: anchor, positive, negative
    anchor = Input(shape=input_shape, name='anchor_input')
    positive = Input(shape=input_shape, name='positive_input')
    negative = Input(shape=input_shape, name='negative_input')
    
    # extract vector represent using CNN based model
    anc_vec = base_model(anchor)
    pos_vec = base_model(positive)
    neg_vec = base_model(negative)
    
    # stack outputs
    stacks = Lambda(lambda x: K.stack(x, axis=1), name='output')([anc_vec, pos_vec, neg_vec])

    # define inputs and outputs
    inputs=[anchor, positive, negative]
    outputs = stacks
    
    # define the triplet model
    model = Model(inputs=inputs, outputs=outputs, name='triplet_net')
    
    return model

# %%
# Define triplet loss
def triplet_loss(y_true, y_pred):
    """ function to compute triplet loss
        margin is predefined coded, manually change if needed
    """
    # define triplet margin
    margin = K.constant(0.3)
    zero = K.constant(0.0)
    
    # get the prediction vector
    anchor, positive, negative = y_pred[:, 0], y_pred[:, 1], y_pred[:, 2]
    
    # compute distance
    pos_distance = K.sum(K.square(anchor - positive), axis=1)
    neg_distance = K.sum(K.square(anchor - negative), axis=1)
    
    # compute loss
    partial_loss = pos_distance - neg_distance + margin
    full_loss = K.sum(K.maximum(partial_loss, zero), axis=0)
    
    return full_loss

# %% [markdown]
# # Build Triplet Model

# %%
# For reproduciable purpose
seed = 42
K.clear_session()
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(seed)
random.seed(seed)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.set_random_seed(seed)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# Define Parameters
img_size = (224, 224, 3)  # target image size

# triplet image generator
train_generator = train_triplet_generator(train_df, batch_size=74, img_size=img_size[:2], 
                                          seed=42, prefix='./data/triplet/train/')

val_generator = val_triplet_generator(val_df, batch_size=64, img_size=img_size[:2], 
                                      seed=42, prefix='./data/triplet/validation/')

# %%
# Define triplet network model
base_model = base_net(input_shape=img_size, trainable=False)
base_model.summary()
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3148: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout1 (Dropout)           (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 2048)              51382272
# _________________________________________________________________
# dropout2 (Dropout)           (None, 2048)              0
# _________________________________________________________________
# fc2 (Dense)                  (None, 512)               1049088
# _________________________________________________________________
# l2_norm (Lambda)             (None, 512)               0
# =================================================================
# Total params: 67,146,048
# Trainable params: 52,431,360
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
triplet_model = triplet_net(base_model=base_model, input_shape=img_size)
triplet_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# anchor_input (InputLayer)       (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# positive_input (InputLayer)     (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# negative_input (InputLayer)     (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# base_net (Sequential)           (None, 512)          67146048    anchor_input[0][0]
#                                                                  positive_input[0][0]
#                                                                  negative_input[0][0]
# __________________________________________________________________________________________________
# output (Lambda)                 (None, 3, 512)       0           base_net[1][0]
#                                                                  base_net[2][0]
#                                                                  base_net[3][0]
# ==================================================================================================
# Total params: 67,146,048
# Trainable params: 52,431,360
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %% [markdown]
# # Fit Triplet Model

# %%
# define learning scheduler
def lr_schedule(epoch):
    """ Learning rate schedule """
    lr = 1e-3
    if epoch > 80:
        lr *= 6e-1
    elif epoch > 60:
        lr *= 7e-1
    elif epoch > 40:
        lr *= 8e-1
    elif epoch > 20:
        lr *= 9e-1
    print('Learning rate: ', lr)
    return lr

# define optimizer
opt = keras.optimizers.Adam(lr=lr_schedule(0))

# Create call backs
checkpoint = ModelCheckpoint(filepath='./models/vgg16-triplet-ckpt.h5', 
                             monitor='val_loss', save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# compile the model
triplet_model.compile(optimizer=opt, loss=triplet_loss)
# Out:
# Learning rate:  0.001

# %%
# fit the mode
history = triplet_model.fit_generator(train_generator, steps_per_epoch=100, epochs=100, 
                                      validation_data=val_generator, validation_steps=48, 
                                      verbose=2, callbacks=callbacks)

triplet_model.save('./models/vgg16-triplet-model.h5')
base_model.save('./models/vgg16-base-model.h5')
pickle.dump(history.history, open('./models/vgg16-triplet-history.p', 'wb'))
_ = gc.collect()
# Out:
# Epoch 1/100
# Learning rate:  0.001
#  - 73s - loss: 13.6784 - val_loss: 9.1813
# Epoch 2/100
# Learning rate:  0.001
#  - 56s - loss: 9.5033 - val_loss: 7.7722
# Epoch 3/100
# Learning rate:  0.001
#  - 56s - loss: 8.3779 - val_loss: 6.9348
# Epoch 4/100
# Learning rate:  0.001
#  - 56s - loss: 7.8738 - val_loss: 6.7183
# Epoch 5/100
# Learning rate:  0.001
#  - 56s - loss: 7.1982 - val_loss: 6.4886
# Epoch 6/100
# Learning rate:  0.001
#  - 56s - loss: 6.8594 - val_loss: 6.3368
# Epoch 7/100
# Learning rate:  0.001
#  - 56s - loss: 6.5319 - val_loss: 6.0750
# Epoch 8/100
# Learning rate:  0.001
#  - 56s - loss: 6.1705 - val_loss: 6.0886
# Epoch 9/100
# Learning rate:  0.001
#  - 56s - loss: 6.3107 - val_loss: 5.7913
# Epoch 10/100
# Learning rate:  0.001
#  - 56s - loss: 5.9853 - val_loss: 5.7632
# Epoch 11/100
# Learning rate:  0.001
#  - 56s - loss: 5.9387 - val_loss: 5.6506
# Epoch 12/100
# Learning rate:  0.001
#  - 56s - loss: 5.5721 - val_loss: 5.7466
# Epoch 13/100
# Learning rate:  0.001
#  - 56s - loss: 5.4977 - val_loss: 5.6572
# Epoch 14/100
# Learning rate:  0.001
#  - 56s - loss: 5.0310 - val_loss: 5.4632
# Epoch 15/100
# Learning rate:  0.001
#  - 57s - loss: 5.1596 - val_loss: 5.4879
# Epoch 16/100
# Learning rate:  0.001
#  - 56s - loss: 5.2127 - val_loss: 5.2236
# Epoch 17/100
# Learning rate:  0.001
#  - 56s - loss: 4.7681 - val_loss: 5.3429
# Epoch 18/100
# Learning rate:  0.001
#  - 56s - loss: 4.9095 - val_loss: 5.1486
# Epoch 19/100
# Learning rate:  0.001
#  - 56s - loss: 4.6170 - val_loss: 5.1837
# Epoch 20/100
# Learning rate:  0.001
#  - 56s - loss: 4.5901 - val_loss: 5.0991
# Epoch 21/100
# Learning rate:  0.001
#  - 56s - loss: 4.5734 - val_loss: 5.4250
# Epoch 22/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 4.5312 - val_loss: 4.9660
# Epoch 23/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 4.3477 - val_loss: 5.0207
# Epoch 24/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 4.3812 - val_loss: 4.9869
# Epoch 25/100
# Learning rate:  0.0009000000000000001
#  - 57s - loss: 4.1370 - val_loss: 4.8484
# Epoch 26/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.9236 - val_loss: 4.8356
# Epoch 27/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 4.0899 - val_loss: 4.8773
# Epoch 28/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.8738 - val_loss: 4.7683
# Epoch 29/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.9760 - val_loss: 4.8741
# Epoch 30/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.9181 - val_loss: 4.7149
# Epoch 31/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.8164 - val_loss: 4.9688
# Epoch 32/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.8368 - val_loss: 4.9162
# Epoch 33/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.8871 - val_loss: 4.8356
# Epoch 34/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.6317 - val_loss: 4.6783
# Epoch 35/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.6509 - val_loss: 4.6765
# Epoch 36/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.6103 - val_loss: 4.5931
# Epoch 37/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.4558 - val_loss: 4.8261
# Epoch 38/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.5252 - val_loss: 4.8354
# Epoch 39/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.7013 - val_loss: 4.5602
# Epoch 40/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.3952 - val_loss: 4.4656
# Epoch 41/100
# Learning rate:  0.0009000000000000001
#  - 56s - loss: 3.4781 - val_loss: 4.5032
# Epoch 42/100
# Learning rate:  0.0008
#  - 56s - loss: 3.2170 - val_loss: 4.6261
# Epoch 43/100
# Learning rate:  0.0008
#  - 56s - loss: 3.2208 - val_loss: 4.4550
# Epoch 44/100
# Learning rate:  0.0008
#  - 56s - loss: 3.4076 - val_loss: 4.6007
# Epoch 45/100
# Learning rate:  0.0008
#  - 56s - loss: 3.2806 - val_loss: 4.3987
# Epoch 46/100
# Learning rate:  0.0008
#  - 56s - loss: 2.9542 - val_loss: 4.3801
# Epoch 47/100
# Learning rate:  0.0008
#  - 56s - loss: 3.1019 - val_loss: 4.2961
# Epoch 48/100
# Learning rate:  0.0008
#  - 56s - loss: 3.0553 - val_loss: 4.4465
# Epoch 49/100
# Learning rate:  0.0008
#  - 56s - loss: 3.0574 - val_loss: 4.4554
# Epoch 50/100
# Learning rate:  0.0008
#  - 56s - loss: 3.0901 - val_loss: 4.3295
# Epoch 51/100
# Learning rate:  0.0008
#  - 56s - loss: 2.8714 - val_loss: 4.3963
# Epoch 52/100
# Learning rate:  0.0008
#  - 56s - loss: 2.9329 - val_loss: 4.3778
# Epoch 53/100
# Learning rate:  0.0008
#  - 56s - loss: 2.8139 - val_loss: 4.3434
# Epoch 54/100
# Learning rate:  0.0008
#  - 56s - loss: 2.7982 - val_loss: 4.4441
# Epoch 55/100
# Learning rate:  0.0008
#  - 56s - loss: 2.6711 - val_loss: 4.3785
# Epoch 56/100
# Learning rate:  0.0008
#  - 56s - loss: 2.6731 - val_loss: 4.2400
# Epoch 57/100
# Learning rate:  0.0008
#  - 56s - loss: 2.6881 - val_loss: 4.3150
# Epoch 58/100
# Learning rate:  0.0008
#  - 56s - loss: 2.7088 - val_loss: 4.6156
# Epoch 59/100
# Learning rate:  0.0008
#  - 56s - loss: 2.8088 - val_loss: 4.2830
# Epoch 60/100
# Learning rate:  0.0008
#  - 56s - loss: 2.6616 - val_loss: 4.2488
# Epoch 61/100
# Learning rate:  0.0008
#  - 56s - loss: 2.7434 - val_loss: 4.3780
# Epoch 62/100
# Learning rate:  0.0007
#  - 56s - loss: 2.5030 - val_loss: 4.3521
# Epoch 63/100
# Learning rate:  0.0007
#  - 56s - loss: 2.4826 - val_loss: 4.3047
# Epoch 64/100
# Learning rate:  0.0007
#  - 56s - loss: 2.4752 - val_loss: 4.1878
# Epoch 65/100
# Learning rate:  0.0007
#  - 56s - loss: 2.6944 - val_loss: 4.3997
# Epoch 66/100
# Learning rate:  0.0007
#  - 56s - loss: 2.5678 - val_loss: 4.3468
# Epoch 67/100
# Learning rate:  0.0007
#  - 56s - loss: 2.3004 - val_loss: 4.4235
# Epoch 68/100
# Learning rate:  0.0007
#  - 56s - loss: 2.4907 - val_loss: 4.2886
# Epoch 69/100
# Learning rate:  0.0007
#  - 57s - loss: 2.4903 - val_loss: 4.2200
# Epoch 70/100
# Learning rate:  0.0007
#  - 56s - loss: 2.3641 - val_loss: 4.1501
# Epoch 71/100
# Learning rate:  0.0007
#  - 56s - loss: 2.3559 - val_loss: 4.2452
# Epoch 72/100
# Learning rate:  0.0007
#  - 56s - loss: 2.4983 - val_loss: 4.2380
# Epoch 73/100
# Learning rate:  0.0007
#  - 56s - loss: 2.0845 - val_loss: 4.1291
# Epoch 74/100
# Learning rate:  0.0007
#  - 56s - loss: 2.2715 - val_loss: 4.0409
# Epoch 75/100
# Learning rate:  0.0007
#  - 56s - loss: 2.3336 - val_loss: 4.6006
# Epoch 76/100
# Learning rate:  0.0007
#  - 56s - loss: 2.2836 - val_loss: 4.2223
# Epoch 77/100
# Learning rate:  0.0007
#  - 56s - loss: 2.2158 - val_loss: 4.3811
# Epoch 78/100
# Learning rate:  0.0007
#  - 56s - loss: 2.2646 - val_loss: 4.2984
# Epoch 79/100
# Learning rate:  0.0007
#  - 56s - loss: 2.2666 - val_loss: 4.1661
# Epoch 80/100
# Learning rate:  0.0007
#  - 56s - loss: 2.2379 - val_loss: 4.0030
# Epoch 81/100
# Learning rate:  0.0007
#  - 56s - loss: 2.2264 - val_loss: 4.2360
# Epoch 82/100
# Learning rate:  0.0006
#  - 56s - loss: 2.2116 - val_loss: 4.2055
# Epoch 83/100
# Learning rate:  0.0006
#  - 56s - loss: 2.1856 - val_loss: 4.2585
# Epoch 84/100
# Learning rate:  0.0006
#  - 56s - loss: 2.1086 - val_loss: 4.4331
# Epoch 85/100
# Learning rate:  0.0006
#  - 58s - loss: 2.0015 - val_loss: 4.0761
# Epoch 86/100
# Learning rate:  0.0006
#  - 56s - loss: 2.0296 - val_loss: 4.2465
# Epoch 87/100
# Learning rate:  0.0006
#  - 56s - loss: 2.0935 - val_loss: 4.3874
# Epoch 88/100
# Learning rate:  0.0006
#  - 56s - loss: 1.8604 - val_loss: 4.2485
# Epoch 89/100
# Learning rate:  0.0006
#  - 56s - loss: 2.1330 - val_loss: 4.1519
# Epoch 90/100
# Learning rate:  0.0006
#  - 56s - loss: 1.9026 - val_loss: 4.0673
# Epoch 91/100
# Learning rate:  0.0006
#  - 56s - loss: 1.9921 - val_loss: 4.1880
# Epoch 92/100
# Learning rate:  0.0006
#  - 56s - loss: 1.9398 - val_loss: 4.1935
# Epoch 93/100
# Learning rate:  0.0006
#  - 56s - loss: 1.9293 - val_loss: 4.1118
# Epoch 94/100
# Learning rate:  0.0006
#  - 56s - loss: 1.9437 - val_loss: 4.2739
# Epoch 95/100
# Learning rate:  0.0006
#  - 56s - loss: 1.9899 - val_loss: 4.1850
# Epoch 96/100
# Learning rate:  0.0006
#  - 56s - loss: 2.0336 - val_loss: 4.2674
# Epoch 97/100
# Learning rate:  0.0006
#  - 56s - loss: 1.8845 - val_loss: 4.1362
# Epoch 98/100
# Learning rate:  0.0006
#  - 56s - loss: 1.9324 - val_loss: 4.5170
# Epoch 99/100
# Learning rate:  0.0006
#  - 56s - loss: 2.0680 - val_loss: 4.1548
# Epoch 100/100
# Learning rate:  0.0006
#  - 56s - loss: 1.8437 - val_loss: 4.2176

# %%
# Visualize the training process
train_loss = history.history['loss']
val_loss = history.history['val_loss']

fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(train_loss, label='Training Loss')
ax.plot(val_loss, label='Validation Loss')
ax.set_title('Loss vs. Epochs', fontsize=16)
ax.set_xlabel('Epochs', fontsize=14)
ax.set_ylabel('Loss', fontsize=14)
ax.legend(fontsize=14)
ax.grid(True)
plt.show()

# %% [markdown]
# # Extract Features using Triplet Network

# %%
train_df = pd.read_csv('./data/triplet/train.csv')
val_df = pd.read_csv('./data/triplet/validation.csv')
test_df = pd.read_csv('./data/triplet/test.csv')

print('Train:\t\t', train_df.shape)
print('Validation:\t', val_df.shape)
print('Test:\t\t', test_df.shape)

print('\nTrain Landmarks:\t', len(train_df['landmark_id'].unique()))
print('Validation Landmarks:\t', len(val_df['landmark_id'].unique()))
print('Test Landmarks:\t\t', len(test_df['landmark_id'].unique()))
# Out:
# Train:		 (113783, 4)
# Validation:	 (22255, 4)
# Test:		 (22391, 4)
#
# Train Landmarks:	 14943
# Validation Landmarks:	 7674
# Test Landmarks:		 14436

# %%
# Load trained model
base_model = load_model('./models/vgg16-base-model.h5')
base_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout1 (Dropout)           (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 2048)              51382272
# _________________________________________________________________
# dropout2 (Dropout)           (None, 2048)              0
# _________________________________________________________________
# fc2 (Dense)                  (None, 512)               1049088
# _________________________________________________________________
# l2_norm (Lambda)             (None, 512)               0
# =================================================================
# Total params: 67,146,048
# Trainable params: 67,146,048
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define train_imgs and test_imgs
train_imgs = np.zeros(shape=(len(train_df), 512), dtype=np.float32)
val_imgs = np.zeros(shape=(len(val_df), 512), dtype=np.float32)
test_imgs = np.zeros(shape=(len(test_df), 512), dtype=np.float32)

# %%
# Process training images
img_ids = train_df['image_id'].values
steps = 20000
for i in range(0, len(train_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(train_df), i + steps)
    for idx in range(start, end):
        if idx % 250 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/train/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    train_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:      20000
# ================================================================================
# Process:      40000
# ================================================================================
# Process:      60000
# ================================================================================
# Process:      80000
# ================================================================================
# Process:     100000
# ========================================================

# %%
# Process validation images
img_ids = val_df['image_id'].values
steps = 4000
for i in range(0, len(val_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(val_df), i + steps)
    for idx in range(start, end):
        if idx % 50 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/validation/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    val_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:       4000
# ================================================================================
# Process:       8000
# ================================================================================
# Process:      12000
# ================================================================================
# Process:      16000
# ================================================================================
# Process:      20000
# ==============================================

# %%
# Process test images
img_ids = test_df['image_id'].values
steps = 4000
for i in range(0, len(test_df), steps):
    tmp_imgs = []
    print('\nProcess: {:10d}'.format(i))
    
    start = i
    end = min(len(test_df), i + steps)
    for idx in range(start, end):
        if idx % 50 == 0:
            print('=', end='')
            
        img_id = img_ids[idx]
        path = './data/triplet/test/' + str(img_id) + '.jpg'
        img = load_img(path, target_size=img_size[:2])
        img = img_to_array(img)
        tmp_imgs.append(img)
        
    tmp_imgs = np.array(tmp_imgs, dtype=np.float32) / 255.0
    tmp_prediction = base_model.predict(tmp_imgs)
    test_imgs[start: end, ] = tmp_prediction
    _ = gc.collect()
# Out:
# Process:          0
# ================================================================================
# Process:       4000
# ================================================================================
# Process:       8000
# ================================================================================
# Process:      12000
# ================================================================================
# Process:      16000
# ================================================================================
# Process:      20000
# ================================================

# %%
print('Train:\t\t', train_imgs.shape)
print('Validation:\t', val_imgs.shape)
print('Test:\t\t', test_imgs.shape)
# Out:
# Train:		 (113783, 512)
# Validation:	 (22255, 512)
# Test:		 (22391, 512)

# %%
# Save to disk
np.save('./data/triplet/train_triplet_vgg16_features.npy', train_imgs)
np.save('./data/triplet/validation_triplet_vgg16_features.npy', val_imgs)
np.save('./data/triplet/test_triplet_vgg16_features.npy', test_imgs)
